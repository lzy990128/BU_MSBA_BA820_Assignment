# %% [markdown]
# # IS 820 Homework 1
#
# Group Member Names: A8
#
# Reminder: you should not be sharing code across groups

# %% [markdown]
# **Warning: make sure your compute environment is set up first.** This homework assignment assumes that you have already installed Anaconda Python 3 and spaCy.

# %% [markdown]
# ### Instructions
# 1. Fill in group name, and member names above
# 2. Fill in the code/text blocks to answer each question.
# 3. Do *not* change any of the existing code provided.
# 4. Run the entire notebook *before* submitting it on blackboard to make sure that the code actually runs without errors. (**Important**: Any code cells that you have entered code for but did not actually execute will be disregarded, so please be sure to actually run your code first and make sure it runs without errors! We may re-run a subset of your code for grading purposes.)

# %% [markdown]
# ### [Problem 1] Basic Text Analysis [45 pts]
#
# This problem involves a mix of Python review (loops, conditionals, counters/dictionaries, sorting) and learning to work with a sizable collection of text data.
#
# You will be looking at a phenomenon of "natural languages" (i.e., human languages, such as English) called *Zipf's law*, which relates how frequently a word occurs in a language to its "rank" (the word with rank 1 is the most frequently occurring word, the word with rank 2 is the second most frequently occurring word, etc). Roughly speaking, the word with rank 1 appears twice as likely as the word with rank 2, and the three times as likely as the word with rank 3, and so forth. (Some details on Zipf's law can be found on [Wikipedia](https://en.wikipedia.org/wiki/Zipf%27s_law).) In this problem, you are going to check whether Zipf's law holds for a real dataset of text documents.
#
# The dataset we look at is a collection of the 100 most popular books downloaded from the [Gutenburg Project](https://www.gutenberg.org/browse/scores/top). These 100 books form the corpus that we consider for this problem. Each file contains the text of a book. We will read in all 100 books.
#
# Note: Please *do not* change the folder name or the path, and make sure you use a relative path (e.g. './HW1_Dataset/*filename*) when reading the files. When grading your homework, we will put your Jupyter notebook file and the dataset in the same folder, and run your code. **You will not receive points for this problem if your code fails to load the data.**
#
# Hint: To list all files that match a certain pattern, you can use the `glob` package. Here's an example usage:
#
# ```python
# import glob
# print(glob.glob('./HW1_Dataset/*.txt'))
# ```
#
# **(a) Warm-up/basic Python review [15 pts across subparts].** This part serves as a warm-up, getting you familiar with the kind of code we will be writing in this class. Note that throughout part (a), your code should **not** be using spaCy.
#
# **Subpart i [5 pts].** Write a loop that iterates through all 100 books; for each book, print out its corresponding file name and also how long the book is in terms of string length (meaning that if we load in the book as a string, we compute the length of the string using the built-in Python function `len`; this is just counting the number of characters).
#
# **Please do not actually print out the contents of each book since many of the books are extremely long, and by printing out all the books' contents, you'll end up creating a Jupyter notebook that has a massive file size.**
#
# Hint: When debugging your code, you may want to first make sure your code runs on a few of the books rather than all 100 (for example, you can start by only having 3 of the text files in `HW1_Dataset`). Once you're confident that your solution is correct on a few text files, then run on all of them! This is a standard approach to debugging code that is meant to handle large datasets.
#
# Your output should look like (although there should be 100 books rather than 3 as shown below; also, the ordering of the books might be different on your machine):
#
# ```
# ./HW1_Dataset/War and Peace by graf Leo Tolstoy (251).txt 3227580
# ./HW1_Dataset/Democracy in America — Volume 1 by Alexis de Tocqueville (147).txt 1148435
# ./HW1_Dataset/Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (501).txt 441034
# ```

# %%
import glob
#print(glob.glob('./HW1_Dataset/*.txt'))

for filenames in glob.glob('./HW1_Dataset/*.txt'):
    print(filenames,len(open(filenames, "r").read()))
# Out:
# ./HW1_Dataset/War and Peace by graf Leo Tolstoy (251).txt 3227580
# ./HW1_Dataset/Democracy in America — Volume 1 by Alexis de Tocqueville (147).txt 1148435
# ./HW1_Dataset/Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (501).txt 441034
# ./HW1_Dataset/The King James Version of the Bible (132).txt 4351846
# ./HW1_Dataset/Et dukkehjem. English by Henrik Ibsen (557).txt 161241
# ./HW1_Dataset/Outpost in the Wilderness_ Fort Wayne, 1706-1828 by Charles Poinsatte (161).txt 363234
# ./HW1_Dataset/The Romance of Lust_ A Classic Victorian erotic novel by Anonymous (294).txt 1051148
# ./HW1_Dataset/The Odyssey by Homer (124).txt 697404
# ./HW1_Dataset/A History of Spanish Literature by James Fitzmaurice-Kelly (109).txt 765918
# ./HW1_Dataset/The Philosophy of Spiritual Activity by Rudolf Steiner (144).txt 545031
# ./HW1_Dataset/My Fifteen Lost Years by Florence Elizabeth Maybrick (499).txt 383694
# ./HW1_Dataset/Prestuplenie i nakazanie. English by Fyodor Dostoyevsky (160).txt 1154508
# ./HW1_Dataset/The History of the Peloponnesian War by Thucydides (122).txt 1200021
# ./HW1_Dataset/Gulliver's Travels into Several Remote Nations of the World by Jonathan Swift (136).txt 600105
# ./HW1_Dataset/The Peddler Spy by W. J. Hamilton (356).txt 197390
# ./HW1_Dataset/Dubliners by James Joyce (219).txt 389199
# ./HW1_Dataset/The Hound of the Baskervilles by Arthur Conan Doyle (223).txt 339188
# ./HW1_Dataset/The Boy Fortune Hunters in China by L. Frank  Baum (215).txt 324452
# ./HW1_Dataset/Leviathan by Thomas Hobbes (417).txt 1231784
# ./HW1_Dataset/The Awakening, and Selected Short Stories by Kate Chopin (192).txt 378936
# ./HW1_Dataset/The Interesting Narrative of the Life of Olaudah Equiano, Or Gustavus Vassa, The African by Equiano (114).txt 471165
# ./HW1_Dataset/Through the Looking-Glass by Lewis Carroll (134).txt 181667
# ./HW1_Dataset/Il Principe. English by Niccolò Machiavelli (428) (Unicode Encoding Conflict).txt 300788
# ./HW1_Dataset/On Liberty by John Stuart Mill (116).txt 325922
# ./HW1_Dataset/The Law of Storms by John Wilson Ross (110).txt 65264
# ./HW1_Dataset/The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson (170).txt 159542
# ./HW1_Dataset/Liberalism by L. T.  Hobhouse (119).txt 305345
# ./HW1_Dataset/Semmering 1912 by Peter Altenberg (221).txt 264946
# ./HW1_Dataset/Les Misérables by Victor Hugo (165) (Unicode Encoding Conflict).txt 3254333
# ./HW1_Dataset/The Count of Monte Cristo, Illustrated by Alexandre Dumas (160).txt 2643849
# ./HW1_Dataset/Alice in Wonderland by Lewis Carroll and Alice Gerstenberg (126).txt 104079
# ./HW1_Dataset/Common Sense by Thomas Paine (297).txt 145353
# ./HW1_Dataset/Narrative of the Captivity and Restoration of Mrs. Mary Rowlandson by Mary White Rowlandson (222).txt 123784
# ./HW1_Dataset/The Divine Comedy by Dante, Illustrated by Dante Alighieri (119).txt 2161
# ./HW1_Dataset/The Importance of Being Earnest_ A Trivial Comedy for Serious People by Oscar Wilde (454).txt 138887
# ./HW1_Dataset/Walden, and On The Duty Of Civil Disobedience by Henry David Thoreau (180).txt 656207
# ./HW1_Dataset/The Yellow Wallpaper by Charlotte Perkins Gilman (462).txt 50841
# ./HW1_Dataset/Jane Eyre_ An Autobiography by Charlotte Brontë (290) (Unicode Encoding Conflict).txt 1049267
# ./HW1_Dataset/The Kama Sutra of Vatsyayana by Vatsyayana (172).txt 351664
# ./HW1_Dataset/Sense and Sensibility by Jane Austen (177).txt 693095
# ./HW1_Dataset/Adventures of Huckleberry Finn by Mark Twain (401).txt 593962
# ./HW1_Dataset/Heart of Darkness by Joseph Conrad (213).txt 229835
# ./HW1_Dataset/The Republic by Plato (246).txt 1214387
# ./HW1_Dataset/The Complete Works of William Shakespeare by William Shakespeare (132).txt 5465100
# ./HW1_Dataset/The Picture of Dorian Gray by Oscar Wilde (282).txt 453169
# ./HW1_Dataset/The Works of Edgar Allan Poe — Volume 2 by Edgar Allan Poe (137).txt 569966
# ./HW1_Dataset/Ulysses by James Joyce (282).txt 1534140
# ./HW1_Dataset/The Federalist Papers by Alexander Hamilton and John Jay and James Madison (116).txt 1167141
# ./HW1_Dataset/Leaves of Grass by Walt Whitman (164).txt 757361
# ./HW1_Dataset/Narrative of the Life of Frederick Douglass, an American Slave by Frederick Douglass (243).txt 244263
# ./HW1_Dataset/A Study in Scarlet by Arthur Conan Doyle (163).txt 262340
# ./HW1_Dataset/Beowulf An Anglo-Saxon Epic Poem (403).txt 292953
# ./HW1_Dataset/The Wendigo by Algernon Blackwood (174).txt 127464
# ./HW1_Dataset/The Scarlet Letter by Nathaniel Hawthorne (211).txt 506975
# ./HW1_Dataset/Persuasion by Jane Austen (2234).txt 486251
# ./HW1_Dataset/The Time Machine by H. G.  Wells (137).txt 198281
# ./HW1_Dataset/The Guardsman by Homer Greene (175).txt 412900
# ./HW1_Dataset/Carmilla by Joseph Sheridan Le Fanu (135).txt 176408
# ./HW1_Dataset/Uncle Tom's Cabin by Harriet Beecher Stowe (108).txt 1025501
# ./HW1_Dataset/A Tale of Two Cities by Charles Dickens (425).txt 776702
# ./HW1_Dataset/Moby Dick; Or, The Whale by Herman Melville (413).txt 1238569
# ./HW1_Dataset/Songs of Innocence, and Songs of Experience by William Blake (166).txt 51724
# ./HW1_Dataset/Dracula by Bram Stoker (461).txt 867141
# ./HW1_Dataset/Emma by Jane Austen (166).txt 902390
# ./HW1_Dataset/Wuthering Heights by Emily Brontë (179) (Unicode Encoding Conflict).txt 669150
# ./HW1_Dataset/Autobiography of Benjamin Franklin by Benjamin Franklin (247).txt 458600
# ./HW1_Dataset/The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson (158).txt 158048
# ./HW1_Dataset/Anne of Green Gables by L. M.  Montgomery (114).txt 580635
# ./HW1_Dataset/The Souls of Black Folk by W. E. B.  Du Bois (172).txt 421336
# ./HW1_Dataset/The Confessions of St. Augustine by Bishop of Hippo Saint Augustine (157).txt 622405
# ./HW1_Dataset/Candide by Voltaire (180).txt 224924
# ./HW1_Dataset/The Legend of Sleepy Hollow by Washington Irving (399).txt 89237
# ./HW1_Dataset/Alice's Adventures in Wonderland by Lewis Carroll (564).txt 163817
# ./HW1_Dataset/Peter Pan by J. M.  Barrie (274).txt 278194
# ./HW1_Dataset/The Wonderful Wizard of Oz by L. Frank  Baum (150).txt 227654
# ./HW1_Dataset/The Innocents Abroad by Mark Twain (108).txt 1126278
# ./HW1_Dataset/The Turn of the Screw by Henry James (185).txt 248089
# ./HW1_Dataset/The Adventures of Tom Sawyer by Mark Twain (371).txt 412712
# ./HW1_Dataset/The Tragedy of Romeo and Juliet by William Shakespeare (131).txt 174128
# ./HW1_Dataset/A Modest Proposal by Jonathan Swift (233).txt 38966
# ./HW1_Dataset/A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens (265).txt 177758
# ./HW1_Dataset/Essays of Michel de Montaigne — Complete by Michel de Montaigne (205).txt 3033575
# ./HW1_Dataset/The Adventures of Sherlock Holmes by Arthur Conan Doyle (447).txt 581864
# ./HW1_Dataset/Robert Greene by Robert Greene (126).txt 760655
# ./HW1_Dataset/Essays by Ralph Waldo Emerson by Ralph Waldo Emerson (239).txt 557197
# ./HW1_Dataset/The Boy Fortune Hunters in the South Seas by L. Frank  Baum (150).txt 266166
# ./HW1_Dataset/Pride and Prejudice by Jane Austen (1003).txt 704192
# ./HW1_Dataset/My Secret Life, Volumes I. to III. by Anonymous (157).txt 1378627
# ./HW1_Dataset/The Mysterious Affair at Styles by Agatha Christie (115).txt 340770
# ./HW1_Dataset/Treasure Island by Robert Louis Stevenson (236).txt 383675
# ./HW1_Dataset/Hedda Gabler by Henrik Ibsen (123).txt 193875
# ./HW1_Dataset/Metamorphosis by Franz Kafka (483).txt 139056
# ./HW1_Dataset/Great Expectations by Charles Dickens (293).txt 1013450
# ./HW1_Dataset/The Life and Adventures of Robinson Crusoe by Daniel Defoe (126).txt 642909
# ./HW1_Dataset/The Iliad by Homer (256).txt 1175588
# ./HW1_Dataset/The Tragical History of Doctor Faustus by Christopher Marlowe (144).txt 143736
# ./HW1_Dataset/Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm (429).txt 540241
# ./HW1_Dataset/Beyond Good and Evil by Friedrich Wilhelm Nietzsche (120).txt 402273
# ./HW1_Dataset/Siddhartha by Hermann Hesse (216).txt 236855
# ./HW1_Dataset/The Faery Queen and Her Knights by Alfred John Church (177).txt 447320

# %% [markdown]
# **Subpart ii [5 pts].** Copy and paste your code from **subpart i** into the code cell below. Then in the code cell below, modify the code so that it prints out the top 15 longest books (in terms of raw string length, which is what you had already computed). In particular, please write your code so that the printout is of the following format:
#
# ```
# 1. <number of characters in longest text file> <filename of longest text file>
# 2. <number of characters in 2nd longest text file> <filename of 2nd longest text file>
# ...
# 15. <number of characters in 15th longest text file> <filename of 15th longest text file>
# ```
#
# Note: only print out information for the top 15 books in the format above; please do not repeat printing what we asked you to print in **subpart i**.

# %%
import glob
#print(glob.glob('./HW1_Dataset/*.txt'))

list100 = list()

for filenames in glob.glob('./HW1_Dataset/*.txt'):
    lenth = len(open(filenames, "r").read())
    list100.append((lenth,filenames))

top15 = sorted(list100,reverse=True)[0:15]

for i in range(0, 15):
    print(f"{i+1}. <{top15[i][0]}> <{top15[i][1]}>")
# Out:
# 1. <5465100> <./HW1_Dataset/The Complete Works of William Shakespeare by William Shakespeare (132).txt>
# 2. <4351846> <./HW1_Dataset/The King James Version of the Bible (132).txt>
# 3. <3254333> <./HW1_Dataset/Les Misérables by Victor Hugo (165) (Unicode Encoding Conflict).txt>
# 4. <3227580> <./HW1_Dataset/War and Peace by graf Leo Tolstoy (251).txt>
# 5. <3033575> <./HW1_Dataset/Essays of Michel de Montaigne — Complete by Michel de Montaigne (205).txt>
# 6. <2643849> <./HW1_Dataset/The Count of Monte Cristo, Illustrated by Alexandre Dumas (160).txt>
# 7. <1534140> <./HW1_Dataset/Ulysses by James Joyce (282).txt>
# 8. <1378627> <./HW1_Dataset/My Secret Life, Volumes I. to III. by Anonymous (157).txt>
# 9. <1238569> <./HW1_Dataset/Moby Dick; Or, The Whale by Herman Melville (413).txt>
# 10. <1231784> <./HW1_Dataset/Leviathan by Thomas Hobbes (417).txt>
# 11. <1214387> <./HW1_Dataset/The Republic by Plato (246).txt>
# 12. <1200021> <./HW1_Dataset/The History of the Peloponnesian War by Thucydides (122).txt>
# 13. <1175588> <./HW1_Dataset/The Iliad by Homer (256).txt>
# 14. <1167141> <./HW1_Dataset/The Federalist Papers by Alexander Hamilton and John Jay and James Madison (116).txt>
# 15. <1154508> <./HW1_Dataset/Prestuplenie i nakazanie. English by Fyodor Dostoyevsky (160).txt>

# %% [markdown]
# **Subpart iii [5 pts].** You should find that some of the books are quite long. Processing very long books will be problematic with spaCy, so we will want to chop up long books into pieces. Note that later on in the course, we shall see that chopping up large amounts of data into small pieces or "batches" is in fact quite common in machine learning since for massive datasets, we often cannot store them in their entirety on a CPU or GPU for processing all at once.
#
# As a toy example, suppose that a book's text is `'cat dog shark spam eggs'` and we want to split it up into batches where each batch has at most 3 words. Then we could split up the book's text into two batches/pieces: `'cat dog shark'` and `'spam eggs'`.
#
# We have provided code for you to do this below.

# %%
import numpy as np

def split_into_batches(book_text, max_num_words_per_batch):
    words_split_on_spaces = book_text.split(' ')
    num_book_pieces = int(np.ceil(len(words_split_on_spaces) / max_num_words_per_batch))
    batches = []
    for piece_idx in range(num_book_pieces):
        start_idx = piece_idx * max_num_words_per_batch
        end_idx = (piece_idx + 1) * max_num_words_per_batch
        if end_idx > len(words_split_on_spaces):
            end_idx = len(words_split_on_spaces)
        book_piece = ' '.join(words_split_on_spaces[start_idx:end_idx])
        batches.append(book_piece)
    return batches

print(split_into_batches('cat dog shark spam eggs', 3))
# Out:
# ['cat dog shark', 'spam eggs']

# %% [markdown]
# Now write a loop that goes through all 100 books again. However, for each book, split it up into batches so that each batch has at most 10000 words. In this case, how many batches are there total across all 100 books? Please write code that computes this number of batches. Your code should print out the following (with the correct total number of batches):
#
# ```
# Total number of batches: <total number of batches across all 100 books>
# ```

# %%
l = list()
for filenames in glob.glob('./HW1_Dataset/*.txt'):
    content = open(filenames, "r").read()
    l.append(len(split_into_batches(content,10000)))

print(f"Total number of batches: <{sum(l)}>")
# Out:
# Total number of batches: <1246>

# %% [markdown]
# **(b) [10 pts]** Now we will finally use spaCy. Note that for this problem, you don't actually need `spaCy`'s named entity recognition or grammatical parsing. Turning these elements off when you instantiate the `nlp` object can substantially speed up your code. To make sure these are off when instantiating the `nlp` object, call:
#
# ```python
# nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser'])
# ```
#
# **Throughout this problem, do not remove stopwords.**
#
# Build a term frequency (raw counts) table that is for all 100 books. Specifically, building on your solution to part (a)-subpart iii, read in a single book at a time and for each book, do the following:
#
#   1. Split it up into batches where each batch has at most 10000 words.
#   2. For each batch:
#     1. Process the batch by separating and lemmatizing the words
#     2. Count the number of times each lemma appears and add these to the frequency table. For simplicity, **do not convert lemmas to lowercase**. (Note that we use raw counts as the "frequency"--do not do any division.) Also, as we explain below, we will only count lemmas that are alphabetic.
#
# Note that just as we had said in part (a): do **not** print out the complete contents of every book since doing so will result in a Jupyter notebook file that is massive.
#
# After looping through all 100 books, you should have the term frequency table for the entire corpus (importantly, the frequency table should not just be for a single book; it should be for all 100 books). Sort the table and print the top 50 most frequent words, along with their frequencies and ranks. Don't worry about ties (for example, if multiple things have the same frequency, it's fine if your solution breaks ties arbitrarily in the sorting).
#
# Note: When counting the lemmas, only include lemmas that consist of alphabetic letters (a-z and A-Z). You can do this with what's called a *regular expression*. For example, to check whether the words "will.i.am" or "Tesla" are alphabetic, you would do the following:
#
# ```python
# import re  # regular expression package
# if re.match('[a-zA-Z]+$', 'will.i.am'):
#     print('will.i.am consists only of alphabetic letters!')
# if re.match('[a-zA-Z]+$', 'Tesla'):
#     print('tesla consists only of alphabetic letters!')
# ```

# %%
l = list()
for filenames in glob.glob('./HW1_Dataset/*.txt'):
    content = open(filenames, "r").read()
    batches = split_into_batches(content,10000)
    for i in batches:
        parsed_text = nlp(i)
        for token in parsed_text:
            l.append(token.lemma_)

# %%
import re
frequency = {}

for token in l:
    if re.match('[a-zA-Z]+$', token):
        if token in frequency:
            frequency[token] += 1
        else:
            frequency[token] = 1

# %%
s_f = dict(sorted(frequency.items(), key=lambda item: item[1], reverse=True))

# %%
s_f
# Out:
# {'the': 702465,
#  'be': 436114,
#  'and': 435424,
#  'of': 386347,
#  'to': 324409,
#  'I': 255129,
#  'a': 233423,
#  'in': 204252,
#  'he': 193622,
#  'that': 159010,
#  'have': 158132,
#  'it': 135431,
#  'not': 111854,
#  'his': 108536,
#  'you': 102595,
#  'with': 101227,
#  'they': 96821,
#  'for': 95320,
#  'as': 90702,
#  'she': 78524,
#  'but': 75599,
#  'my': 73983,
#  'do': 68754,
#  'at': 64947,
#  'on': 62833,
#  'by': 61274,
#  'this': 61240,
#  'we': 60300,
#  'which': 58868,
#  'all': 58636,
#  'say': 58348,
#  'from': 50095,
#  'so': 47999,
#  'or': 47810,
#  'her': 42838,
#  'one': 41123,
#  'will': 40920,
#  'man': 39585,
#  'their': 38418,
#  'what': 37851,
#  'no': 37808,
#  'there': 37209,
#  'if': 34898,
#  'go': 33897,
#  'when': 33587,
#  'an': 32517,
#  'come': 32358,
#  'see': 32024,
#  'would': 31289,
#  'who': 30934,
#  'make': 30435,
#  'your': 28735,
#  'then': 27348,
#  'out': 26865,
#  'know': 25566,
#  'up': 25364,
#  'more': 25130,
#  'take': 23953,
#  'other': 23711,
#  'shall': 23625,
#  'now': 23457,
#  'well': 23062,
#  'can': 22532,
#  'our': 21733,
#  'any': 21652,
#  'time': 21461,
#  'into': 21283,
#  'could': 21008,
#  'give': 20232,
#  'upon': 20178,
#  'good': 20151,
#  'some': 19898,
#  'than': 19656,
#  'very': 19244,
#  'like': 18529,
#  'think': 18223,
#  'day': 18044,
#  'look': 17311,
#  'should': 17156,
#  'only': 17042,
#  'may': 16879,
#  'hand': 16874,
#  'such': 16808,
#  'great': 16424,
#  'how': 16260,
#  'about': 16223,
#  'these': 16093,
#  'thing': 15843,
#  'before': 15721,
#  'must': 15369,
#  'two': 14515,
#  'work': 14411,
#  'after': 14205,
#  'its': 14184,
#  'tell': 14167,
#  'little': 13944,
#  'get': 13924,
#  'own': 13628,
#  'find': 13617,
#  'down': 13445,
#  'much': 13365,
#  'long': 13265,
#  'where': 13223,
#  'over': 13114,
#  'first': 12933,
#  'thou': 12857,
#  'let': 12725,
#  'here': 12601,
#  'never': 12410,
#  'way': 12386,
#  'again': 12238,
#  'hear': 12030,
#  'those': 11768,
#  'without': 11656,
#  'every': 11541,
#  'old': 11459,
#  'most': 11438,
#  'himself': 11411,
#  'eye': 11399,
#  'leave': 11234,
#  'life': 11221,
#  'place': 11145,
#  'yet': 11043,
#  'thy': 10783,
#  'God': 10587,
#  'even': 10582,
#  'house': 10496,
#  'unto': 10408,
#  'word': 10377,
#  'too': 10313,
#  'love': 10296,
#  'speak': 10092,
#  'might': 10072,
#  'away': 10008,
#  'same': 9994,
#  'people': 9770,
#  'nothing': 9620,
#  'seem': 9457,
#  'call': 9400,
#  'many': 9181,
#  'still': 9162,
#  'stand': 9078,
#  'thee': 9032,
#  'woman': 9008,
#  'another': 8896,
#  'head': 8886,
#  'through': 8827,
#  'turn': 8790,
#  'bring': 8756,
#  'put': 8716,
#  'back': 8647,
#  'against': 8574,
#  'use': 8573,
#  'feel': 8509,
#  'child': 8411,
#  'night': 8368,
#  'also': 8352,
#  'though': 8328,
#  'off': 8232,
#  'ask': 8226,
#  'face': 8217,
#  'just': 8186,
#  'Project': 8147,
#  'year': 8128,
#  'Gutenberg': 8108,
#  'father': 8095,
#  'right': 8040,
#  'why': 8025,
#  'last': 8004,
#  'part': 7943,
#  'nor': 7933,
#  'under': 7920,
#  'because': 7895,
#  'while': 7776,
#  'name': 7729,
#  'keep': 7682,
#  'begin': 7647,
#  'ever': 7602,
#  'son': 7584,
#  'heart': 7430,
#  'once': 7366,
#  'far': 7361,
#  'pass': 7338,
#  'young': 7324,
#  'room': 7216,
#  'fall': 7183,
#  'mean': 7128,
#  'friend': 7102,
#  'world': 7065,
#  'LORD': 7055,
#  'want': 6904,
#  'three': 6898,
#  'myself': 6843,
#  'both': 6823,
#  'mind': 6724,
#  'live': 6692,
#  'hold': 6676,
#  'door': 6562,
#  'king': 6493,
#  'whom': 6475,
#  'set': 6433,
#  'yes': 6424,
#  'side': 6421,
#  'always': 6420,
#  'return': 6335,
#  'lie': 6325,
#  'sit': 6293,
#  'o': 6191,
#  'answer': 6130,
#  'end': 6070,
#  'cry': 6035,
#  'become': 5875,
#  'thus': 5852,
#  'light': 5814,
#  'die': 5782,
#  'open': 5778,
#  'soon': 5750,
#  'each': 5706,
#  'send': 5701,
#  'power': 5689,
#  'follow': 5683,
#  'law': 5681,
#  'something': 5645,
#  'death': 5637,
#  'whole': 5628,
#  'enter': 5537,
#  'moment': 5526,
#  'full': 5511,
#  'arm': 5511,
#  'mother': 5488,
#  'therefore': 5477,
#  'tm': 5474,
#  'ye': 5396,
#  'bear': 5390,
#  'between': 5354,
#  'soul': 5274,
#  'hath': 5097,
#  'fear': 5076,
#  'wish': 5067,
#  'sir': 5035,
#  'present': 5034,
#  'state': 5024,
#  'run': 5014,
#  'round': 5009,
#  'new': 4999,
#  'oh': 4982,
#  'body': 4967,
#  'themselves': 4964,
#  'form': 4958,
#  'voice': 4955,
#  'write': 4930,
#  'dear': 4924,
#  'show': 4918,
#  'quite': 4906,
#  'believe': 4864,
#  'order': 4864,
#  'land': 4856,
#  'true': 4836,
#  'de': 4816,
#  'among': 4816,
#  'till': 4807,
#  'hour': 4772,
#  'foot': 4751,
#  'appear': 4748,
#  'home': 4743,
#  'high': 4716,
#  'poor': 4712,
#  'country': 4689,
#  'half': 4689,
#  'water': 4658,
#  'point': 4649,
#  'rest': 4623,
#  'receive': 4620,
#  'person': 4611,
#  'hope': 4605,
#  'whose': 4564,
#  'draw': 4523,
#  'cause': 4519,
#  'meet': 4513,
#  'talk': 4510,
#  'walk': 4484,
#  'matter': 4459,
#  'enough': 4426,
#  'few': 4410,
#  'reason': 4349,
#  'wife': 4340,
#  'near': 4297,
#  'understand': 4275,
#  'thought': 4273,
#  'lay': 4271,
#  'reply': 4261,
#  'lose': 4255,
#  'however': 4253,
#  'almost': 4206,
#  'together': 4203,
#  'indeed': 4199,
#  'within': 4196,
#  'rise': 4190,
#  'kind': 4175,
#  'fire': 4164,
#  'nature': 4150,
#  'try': 4136,
#  'since': 4135,
#  'remain': 4125,
#  'manner': 4106,
#  'bed': 4106,
#  'rather': 4072,
#  'carry': 4063,
#  'case': 4053,
#  'course': 4050,
#  'morning': 4034,
#  'herself': 3992,
#  'dead': 3919,
#  'small': 3907,
#  'city': 3904,
#  'sea': 3903,
#  'brother': 3897,
#  'less': 3880,
#  'boy': 3860,
#  'anything': 3843,
#  'Miss': 3835,
#  'bad': 3832,
#  'help': 3830,
#  'certain': 3822,
#  'read': 3807,
#  'question': 3799,
#  'break': 3776,
#  'itself': 3775,
#  'Lord': 3766,
#  'earth': 3762,
#  'hundred': 3744,
#  'letter': 3741,
#  'mine': 3734,
#  'grow': 3725,
#  'whether': 3724,
#  'pay': 3699,
#  'war': 3696,
#  'girl': 3668,
#  'art': 3665,
#  'close': 3649,
#  'alone': 3642,
#  'ship': 3633,
#  'master': 3629,
#  'perhaps': 3613,
#  'subject': 3605,
#  'force': 3596,
#  'next': 3566,
#  'often': 3564,
#  'lord': 3558,
#  'either': 3555,
#  'large': 3555,
#  'white': 3545,
#  'desire': 3535,
#  'neither': 3521,
#  'lady': 3499,
#  'thousand': 3491,
#  'already': 3488,
#  'sleep': 3488,
#  'pleasure': 3456,
#  'smile': 3452,
#  'four': 3441,
#  'change': 3435,
#  'forth': 3431,
#  'money': 3416,
#  'spirit': 3402,
#  'heaven': 3390,
#  'horse': 3387,
#  'idea': 3369,
#  'term': 3324,
#  'need': 3324,
#  'sort': 3319,
#  'sure': 3312,
#  'truth': 3297,
#  'wait': 3287,
#  'lead': 3286,
#  'second': 3284,
#  'towards': 3234,
#  'servant': 3212,
#  'ground': 3204,
#  'five': 3202,
#  'air': 3192,
#  'sound': 3191,
#  'number': 3190,
#  'eat': 3181,
#  'free': 3169,
#  'play': 3164,
#  'suppose': 3160,
#  'daughter': 3148,
#  'move': 3125,
#  'seek': 3122,
#  'general': 3122,
#  'book': 3118,
#  'strong': 3109,
#  'sister': 3102,
#  'throw': 3095,
#  'remember': 3092,
#  'above': 3087,
#  'behind': 3053,
#  'copy': 3048,
#  'until': 3044,
#  'fact': 3042,
#  'blood': 3040,
#  'sight': 3008,
#  'really': 2999,
#  'wall': 2992,
#  'fellow': 2989,
#  'care': 2985,
#  'opinion': 2972,
#  'least': 2968,
#  'black': 2932,
#  'along': 2928,
#  'public': 2921,
#  'States': 2918,
#  'tear': 2898,
#  'table': 2886,
#  'King': 2875,
#  'gentleman': 2866,
#  'stop': 2856,
#  'consider': 2853,
#  'sense': 2853,
#  'age': 2831,
#  'please': 2818,
#  'sometimes': 2807,
#  'step': 2803,
#  'laugh': 2784,
#  'else': 2776,
#  'tree': 2772,
#  'family': 2761,
#  'everything': 2745,
#  'doubt': 2745,
#  'yourself': 2743,
#  'Israel': 2734,
#  'happen': 2726,
#  'learn': 2726,
#  'none': 2713,
#  'human': 2709,
#  'fair': 2702,
#  'act': 2692,
#  'able': 2691,
#  'enemy': 2690,
#  'window': 2687,
#  'command': 2682,
#  'street': 2678,
#  'business': 2673,
#  'low': 2672,
#  'strike': 2661,
#  'Prince': 2656,
#  'government': 2655,
#  'reach': 2654,
#  'electronic': 2647,
#  'stay': 2645,
#  'strange': 2636,
#  'husband': 2629,
#  'accord': 2629,
#  'add': 2624,
#  'provide': 2620,
#  'ought': 2611,
#  'kill': 2608,
#  'continue': 2604,
#  'happy': 2587,
#  'watch': 2584,
#  'raise': 2582,
#  'short': 2577,
#  'evening': 2567,
#  'minute': 2562,
#  'common': 2556,
#  'charge': 2551,
#  'several': 2545,
#  'hard': 2544,
#  'town': 2532,
#  'hair': 2521,
#  'Thou': 2520,
#  'offer': 2511,
#  'save': 2488,
#  'forget': 2483,
#  'tis': 2456,
#  'dark': 2444,
#  'action': 2436,
#  'ten': 2435,
#  'mouth': 2432,
#  'god': 2426,
#  'interest': 2423,
#  'fine': 2420,
#  'twenty': 2407,
#  'John': 2405,
#  'Sir': 2405,
#  'view': 2392,
#  'account': 2391,
#  'object': 2380,
#  'ready': 2373,
#  'Foundation': 2372,
#  'possible': 2371,
#  'cut': 2371,
#  'evil': 2369,
#  'count': 2368,
#  'pray': 2363,
#  'fly': 2360,
#  'knowledge': 2352,
#  'suddenly': 2349,
#  'touch': 2338,
#  'honour': 2338,
#  'drink': 2324,
#  'allow': 2321,
#  'distribute': 2318,
#  'field': 2312,
#  'fight': 2306,
#  'line': 2306,
#  'nation': 2303,
#  'different': 2291,
#  'observe': 2289,
#  'notice': 2283,
#  'drive': 2275,
#  'purpose': 2274,
#  'feeling': 2273,
#  'expect': 2271,
#  'wind': 2270,
#  'peace': 2263,
#  'stone': 2263,
#  'sun': 2262,
#  'judge': 2253,
#  'serve': 2248,
#  'ear': 2245,
#  'thank': 2234,
#  'ill': 2234,
#  'effect': 2226,
#  'month': 2226,
#  'wonder': 2219,
#  'around': 2216,
#  'chapter': 2192,
#  'soldier': 2182,
#  'piece': 2181,
#  'deep': 2176,
#  'wear': 2175,
#  'promise': 2170,
#  'during': 2167,
#  'past': 2165,
#  'concern': 2161,
#  'listen': 2159,
#  'service': 2157,
#  'sweet': 2152,
#  'agree': 2148,
#  'paper': 2148,
#  'suffer': 2133,
#  'start': 2128,
#  'ah': 2113,
#  'marry': 2109,
#  'shalt': 2108,
#  'rich': 2105,
#  'dream': 2098,
#  'certainly': 2095,
#  'burn': 2091,
#  'army': 2088,
#  'particular': 2081,
#  'hast': 2080,
#  'lip': 2071,
#  'necessary': 2060,
#  'Tom': 2057,
#  'except': 2053,
#  'fortune': 2053,
#  'kiss': 2051,
#  'catch': 2045,
#  'trouble': 2044,
#  'prince': 2041,
#  'dress': 2041,
#  'clear': 2041,
#  'behold': 2039,
#  'court': 2037,
#  'six': 2036,
#  'party': 2027,
#  'joy': 2025,
#  'condition': 2024,
#  'gold': 2018,
#  'shake': 2015,
#  'early': 2002,
#  'regard': 2001,
#  'Pierre': 2000,
#  'cold': 1979,
#  'battle': 1976,
#  'prove': 1975,
#  'visit': 1971,
#  'fill': 1970,
#  'hang': 1959,
#  'seat': 1955,
#  'wood': 1953,
#  'beautiful': 1952,
#  'spend': 1950,
#  'natural': 1943,
#  'choose': 1940,
#  'self': 1939,
#  'character': 1938,
#  'United': 1931,
#  'strength': 1928,
#  'CHAPTER': 1927,
#  'agreement': 1927,
#  'blow': 1913,
#  'noble': 1910,
#  'finger': 1908,
#  'experience': 1900,
#  'company': 1899,
#  'late': 1897,
#  'occasion': 1895,
#  'dare': 1890,
#  'produce': 1888,
#  'spring': 1879,
#  'chief': 1871,
#  'respect': 1865,
#  'rule': 1865,
#  'officer': 1861,
#  'mark': 1861,
#  'duty': 1853,
#  'bind': 1845,
#  'beyond': 1842,
#  'arrive': 1837,
#  'pain': 1832,
#  'sword': 1826,
#  'afterwards': 1826,
#  'Anne': 1816,
#  'seven': 1813,
#  'Mary': 1810,
#  'red': 1809,
#  'approach': 1804,
#  'easy': 1801,
#  'story': 1799,
#  'drop': 1798,
#  'clothe': 1792,
#  'danger': 1787,
#  'sign': 1783,
#  'individual': 1782,
#  'affair': 1781,
#  'although': 1781,
#  'escape': 1780,
#  'fancy': 1775,
#  'deal': 1771,
#  'cover': 1768,
#  'require': 1764,
#  'pretty': 1762,
#  'discover': 1762,
#  'society': 1761,
#  'sin': 1760,
#  'river': 1758,
#  'authority': 1758,
#  'creature': 1751,
#  'doctor': 1751,
#  'beauty': 1749,
#  'road': 1749,
#  'include': 1748,
#  'immediately': 1742,
#  'glance': 1736,
#  'Thy': 1736,
#  'teach': 1730,
#  'besides': 1729,
#  'hide': 1720,
#  'shoulder': 1718,
#  'forward': 1714,
#  'wrong': 1714,
#  'copyright': 1711,
#  'secret': 1708,
#  'heavy': 1707,
#  'fast': 1706,
#  'gate': 1705,
#  'chance': 1700,
#  'boat': 1697,
#  'post': 1697,
#  'justice': 1695,
#  'tongue': 1693,
#  'note': 1691,
#  'cast': 1691,
#  'captain': 1688,
#  'afraid': 1684,
#  'leg': 1678,
#  'wise': 1674,
#  'wound': 1666,
#  'destroy': 1664,
#  'study': 1663,
#  'third': 1663,
#  'prepare': 1663,
#  'office': 1663,
#  'real': 1661,
#  'State': 1658,
#  'week': 1653,
#  'future': 1649,
#  'fit': 1640,
#  'circumstance': 1639,
#  'priest': 1632,
#  'passion': 1627,
#  'hardly': 1621,
#  'thine': 1616,
#  'virtue': 1611,
#  'silence': 1610,
#  'youth': 1608,
#  'effort': 1606,
#  'judgment': 1596,
#  'prick': 1595,
#  'donation': 1591,
#  'address': 1588,
#  'Mr': 1586,
#  'history': 1584,
#  'glad': 1583,
#  'nearly': 1580,
#  'possess': 1579,
#  'content': 1577,
#  'perceive': 1577,
#  'cross': 1573,
#  'dog': 1572,
#  'mention': 1570,
#  'liberty': 1569,
#  'corner': 1569,
#  'attempt': 1568,
#  'England': 1566,
#  'whatever': 1561,
#  'front': 1560,
#  'sail': 1555,
#  'expression': 1553,
#  'proceed': 1551,
#  'attention': 1548,
#  'unless': 1547,
#  'plain': 1544,
#  'increase': 1542,
#  'shore': 1542,
#  'measure': 1534,
#  'impossible': 1530,
#  'position': 1527,
#  'express': 1522,
#  'chair': 1522,
#  'wild': 1518,
#  'length': 1515,
#  'obtain': 1512,
#  'wine': 1511,
#  'fix': 1511,
#  'saith': 1510,
#  'repeat': 1500,
#  'accept': 1500,
#  'imagine': 1499,
#  'ourselves': 1495,
#  'bow': 1493,
#  'principle': 1493,
#  'glass': 1492,
#  'cunt': 1491,
#  'former': 1487,
#  'press': 1484,
#  'grace': 1483,
#  'deliver': 1482,
#  'dinner': 1476,
#  'fail': 1476,
#  'difficulty': 1475,
#  'trust': 1474,
#  'influence': 1471,
#  'garden': 1470,
#  'gain': 1469,
#  'prisoner': 1467,
#  'delight': 1467,
#  'figure': 1466,
#  'across': 1462,
#  'faith': 1458,
#  'slave': 1454,
#  'remove': 1453,
#  'lift': 1451,
#  'event': 1450,
#  'remark': 1449,
#  'contain': 1448,
#  'big': 1446,
#  'arise': 1445,
#  'build': 1442,
#  'degree': 1435,
#  'single': 1435,
#  'Joe': 1433,
#  'sing': 1430,
#  'shadow': 1427,
#  'toward': 1423,
#  'fool': 1418,
#  'paragraph': 1417,
#  'join': 1416,
#  'mile': 1416,
#  'contrary': 1413,
#  'beat': 1408,
#  'create': 1406,
#  'advantage': 1403,
#  'pull': 1399,
#  'grave': 1394,
#  'exist': 1394,
#  'below': 1392,
#  'wide': 1392,
#  'gaze': 1391,
#  'school': 1391,
#  'support': 1390,
#  'enjoy': 1389,
#  'France': 1389,
#  'presence': 1384,
#  'seize': 1384,
#  'conduct': 1383,
#  'doth': 1383,
#  'aside': 1377,
#  'easily': 1373,
#  'instead': 1371,
#  'sake': 1371,
#  'glory': 1371,
#  'outside': 1371,
#  'stranger': 1370,
#  'especially': 1356,
#  'hill': 1348,
#  'advance': 1348,
#  'Marius': 1345,
#  'appearance': 1344,
#  'conversation': 1344,
#  'report': 1341,
#  'terrible': 1340,
#  'distance': 1339,
#  'ago': 1338,
#  'prevent': 1336,
#  'later': 1331,
#  'hate': 1327,
#  'ring': 1327,
#  'belong': 1326,
#  'praise': 1325,
#  'private': 1324,
#  'share': 1323,
#  'render': 1321,
#  'Madame': 1318,
#  'Paris': 1318,
#  'vain': 1317,
#  'top': 1317,
#  'perform': 1315,
#  'island': 1314,
#  'quiet': 1313,
#  'perfect': 1305,
#  'pity': 1303,
#  'admit': 1303,
#  'demand': 1303,
#  'shout': 1302,
#  'passage': 1302,
#  'Jesus': 1302,
#  'result': 1296,
#  'knee': 1294,
#  'worth': 1294,
#  'declare': 1292,
#  'taste': 1291,
#  'pale': 1290,
#  'citizen': 1289,
#  'fee': 1289,
#  'attend': 1288,
#  'Archive': 1288,
#  'gather': 1286,
#  'example': 1286,
#  'attack': 1285,
#  'beast': 1284,
#  'breast': 1283,
#  'refuse': 1283,
#  'wealth': 1281,
#  'memory': 1278,
#  'breath': 1278,
#  'latter': 1277,
#  'swear': 1277,
#  'sink': 1277,
#  'ancient': 1276,
#  'Literary': 1276,
#  'explain': 1271,
#  'mighty': 1271,
#  'happiness': 1270,
#  'KING': 1270,
#  'carriage': 1269,
#  'silent': 1268,
#  'comfort': 1268,
#  'race': 1268,
#  'guard': 1267,
#  'direct': 1267,
#  'sell': 1266,
#  'rock': 1266,
#  'buy': 1265,
#  'settle': 1262,
#  'Jean': 1261,
#  'crowd': 1260,
#  'beside': 1259,
#  'cease': 1258,
#  'flesh': 1258,
#  'whale': 1256,
#  'floor': 1254,
#  'David': 1251,
#  'pocket': 1249,
#  'church': 1248,
#  'hat': 1247,
#  'plan': 1245,
#  'false': 1245,
#  'french': 1242,
#  'picture': 1238,
#  'beg': 1236,
#  'Christ': 1236,
#  'anyone': 1235,
#  'language': 1231,
#  'companion': 1230,
#  'witness': 1227,
#  'holy': 1225,
#  'equal': 1223,
#  'middle': 1223,
#  'quickly': 1223,
#  'straight': 1221,
#  'ride': 1221,
#  'vessel': 1219,
#  'Andrew': 1218,
#  'simple': 1216,
#  'bright': 1215,
#  'Athenians': 1214,
#  'occur': 1213,
#  'instant': 1213,
#  'sorrow': 1212,
#  'thirty': 1212,
#  'access': 1210,
#  'direction': 1208,
#  'Moses': 1207,
#  'shut': 1205,
#  'opportunity': 1203,
#  'Footnote': 1202,
#  'usual': 1201,
#  'merely': 1201,
#  'Jane': 1200,
#  'finish': 1197,
#  'morrow': 1196,
#  'bird': 1195,
#  'ruin': 1191,
#  'proper': 1190,
#  'probably': 1188,
#  'devil': 1186,
#  'tone': 1185,
#  'bread': 1185,
#  'New': 1183,
#  'board': 1182,
#  'determine': 1180,
#  'marriage': 1180,
#  'cloud': 1179,
#  'scene': 1178,
#  'flower': 1178,
#  'green': 1177,
#  'oblige': 1177,
#  'neck': 1175,
#  'iron': 1174,
#  'silver': 1172,
#  'fault': 1172,
#  'member': 1171,
#  'quarter': 1171,
#  'bottom': 1171,
#  'commit': 1162,
#  'whisper': 1162,
#  'mountain': 1161,
#  'news': 1158,
#  'sky': 1158,
#  'rush': 1156,
#  'darkness': 1155,
#  'thereof': 1155,
#  'French': 1152,
#  'perfectly': 1152,
#  'describe': 1152,
#  'intend': 1152,
#  'th': 1151,
#  'blue': 1150,
#  'utter': 1149,
#  'property': 1147,
#  'spread': 1145,
#  'weep': 1145,
#  'possession': 1144,
#  'Monte': 1143,
#  'exercise': 1142,
#  'class': 1138,
#  'surprise': 1135,
#  'eight': 1134,
#  'movement': 1133,
#  'gentle': 1131,
#  'fresh': 1131,
#  'Cristo': 1130,
#  'mere': 1127,
#  'hence': 1127,
#  'warm': 1125,
#  'spot': 1123,
#  'succeed': 1120,
#  'bless': 1120,
#  'offering': 1120,
#  'sacrifice': 1119,
#  'London': 1117,
#  'wave': 1114,
#  'village': 1112,
#  'engage': 1111,
#  'being': 1108,
#  'favour': 1106,
#  'relation': 1103,
#  'Henry': 1103,
#  'mercy': 1102,
#  'complete': 1101,
#  'Valjean': 1098,
#  'journey': 1096,
#  'shame': 1093,
#  'Lady': 1093,
#  'assure': 1091,
#  'chamber': 1091,
#  'value': 1090,
#  'pause': 1088,
#  'search': 1087,
#  'host': 1087,
#  'yield': 1087,
#  'necessity': 1086,
#  'fifty': 1085,
#  'worthy': 1083,
#  'exclaim': 1082,
#  ...}

# %%
df = pd.DataFrame.from_dict(s_f,orient='index',columns=['count'])

# %%
df[:50]
# Out:
#         count
# the    702465
# be     436114
# and    435424
# of     386347
# to     324409
# I      255129
# a      233423
# in     204252
# he     193622
# that   159010
# have   158132
# it     135431
# not    111854
# his    108536
# you    102595
# with   101227
# they    96821
# for     95320
# as      90702
# she     78524
# but     75599
# my      73983
# do      68754
# at      64947
# on      62833
# by      61274
# this    61240
# we      60300
# which   58868
# all     58636
# say     58348
# from    50095
# so      47999
# or      47810
# her     42838
# one     41123
# will    40920
# man     39585
# their   38418
# what    37851
# no      37808
# there   37209
# if      34898
# go      33897
# when    33587
# an      32517
# come    32358
# see     32024
# would   31289
# who     30934

# %% [markdown]
# **(c) [10 pts]** Visualize the frequency table by plotting a **raw scatter plot** (put frequency as the y-axis and rank as the x-axis), and a **log-log plot** (use logarithmic scales on both the x- and y- axes). Note that this should be for all words and not only the top 50. As before, for the ranks, do not worry about ties, i.e., break ties arbitrarily.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df['rank'] = df['count'].rank(ascending=False,method='first')

df
# Out:
#                     count      rank
# the                702465       1.0
# be                 436114       2.0
# and                435424       3.0
# of                 386347       4.0
# to                 324409       5.0
# ...                   ...       ...
# Vedder                  1  110511.0
# adventuresomeness       1  110512.0
# oldster                 1  110513.0
# Outlook                 1  110514.0
# AVENUE                  1  110515.0
#
# [110515 rows x 2 columns]

# %%
# Raw scatter plot
plt.scatter(df['rank'], df['count'])
plt.show()

# %%
# Log-log plot 
plt.scatter(np.log10(df['rank']), np.log10(df['count']))
plt.show()

# %% [markdown]
# **(d) [10 pts across subparts]** Let's now try to make sense of the very last plot in part **(c)**. Zipf's law states that term frequency is governed by a power law, i.e. the relationship between term frequency and rank can be approximated by $f(r) = cr^{-1}$, where $f(r)$ is the frequency of the term at rank $r$, $r$ is the rank of a term, and $c$ is a constant that is approximately 0.1*(corpus size) for English.
#
# Please answer the following questions:
#
# **Subpart i [3 pts].** What do you observe in the log-log plot above? Is this consist with the power law?

# %% [markdown]
# If we log both side of the power law, the equation would become log(f(r)) = log(c) -1 * log(r). log(c) is roughly -1. The coefficient of the equation is highly negative which is constant with the log log plot above.

# %% [markdown]
# **Subpart ii [4 pts].** Think of the corpus as a (large) unigram bag of words. Following the analogy from lecture, imagine drawing a single word from this big bag (note that we are assuming that we've lemmatized the words and also filtered out non-alphabetic words; thus what remains in the bag are actually alphabetic lemmas). What is the probability of drawing one of the 4 most frequent alphabetic lemmas? What is the probability of drawing one of the 50 most frequent alphabetic lemmas? Answer these two questions using code rather than just entering in the final answers as numbers.

# %%
print(f"Probability of drawing one of the 4 most frequent alphabetic lemmas: {sum(df['count'][:4])/sum(df['count'])}")
print(f"Probability of drawing one of the 50 most frequent alphabetic lemmas:{sum(df['count'][:50])/sum(df['count'])}")
# Out:
# Probability of drawing one of the 4 most frequent alphabetic lemmas: 0.16224400336116176
# Probability of drawing one of the 50 most frequent alphabetic lemmas:0.48310940071723874

# %% [markdown]
# **Subpart iii [3 pts].** What proportion of the alphabetic lemmas occur only once? What proportion of the alphabetic lemmas occur fewer than 10 times?

# %%
print(f"Occur only once: {(df[df['count'] == 1]['count']).shape[0]/(df['count']).shape[0]}")
print(f"Occur fewer than 10 times: {(df[df['count'] < 10]['count'].shape[0]/(df['count']).shape[0])}")
# Out:
# Occur only once: 0.44752296068407005
# Occur fewer than 10 times: 0.7815500158349545

# %% [markdown]
# ### [Problem 2] Entity Recognition and Pointwise Mutual Information (PMI) [55 pts]
# By using the entity recognition system in `spaCy`, let's identify named entities from newspaper articles. You'll be using Reuters corpus which contains more than ten thousand newspaper articles. To run the code below, you need to download the Reuters dataset. To do so, in a terminal/command line (recall that you can open a terminal from Jupyter's webpage that shows all the files, which by default is [http://localhost:8888/tree](http://localhost:8888/tree)), start up Python and enter:
#
# ```python
# import nltk
# nltk.download('reuters')
# ```
#
# Then proceed to the problem subparts below.
#
# Note that in this problem you will need named entity recognition but not grammatical parsing. Hence, you will want to instantiate the nlp object by calling:
#
# ```python
# nlp = spacy.load('en_core_web_sm', disable=['parser'])
# ```

# %% [markdown]
# **(a) [15 pts]** Draw a bar chart in which one of the axes shows entity labels and the other shows the frequency of the corresponding label. Use the variables `reuters_nlp` and `label_counter` provided in the code below.

# %%
import nltk
nltk.download('reuters')
# Out:
# [nltk_data] Downloading package reuters to /Users/ryanli/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# True

# %%
import matplotlib.pyplot as plt
from collections import Counter
from nltk.corpus import reuters
import re
import spacy
nlp = spacy.load('en_core_web_sm', disable=['parser', 'tagger'])

reuters_fileids = reuters.fileids() # hint: when first debugging, consider looking at just the first few
reuters_nlp = [nlp(re.sub('\s+',' ', reuters.raw(i)).strip()) for i in reuters_fileids]
label_counter = Counter()

# %%
label_counter = Counter()
for tokens in reuters_nlp:
    for token in tokens.ents:
        original_token_text = token.label_
        label_counter[original_token_text] += 1
        # note: a shorter way to write the line above is: histogram[original_token_text] += 1

sorted_token_count_pairs = label_counter.most_common()
for token, count in sorted_token_count_pairs:
    print(token, ":", count)
# Out:
# CARDINAL : 59787
# ORG : 50331
# DATE : 36747
# GPE : 21609
# PERSON : 11958
# MONEY : 7932
# NORP : 6353
# QUANTITY : 4714
# PRODUCT : 2188
# LOC : 1682
# ORDINAL : 1203
# LAW : 1049
# TIME : 908
# FAC : 294
# WORK_OF_ART : 217
# PERCENT : 152
# EVENT : 145
# LANGUAGE : 25

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn') 
# %config InlineBackend.figure_format = 'retina'  


top_label = [label for label, count in sorted_token_count_pairs]
top_counts = [count for label, count in sorted_token_count_pairs]
plt.bar(range(18), top_counts)
plt.xticks(range(18), top_label, rotation=90)
plt.xlabel('Label')
plt.ylabel('Raw count')
# Out:
# Text(0, 0.5, 'Raw count')

# %% [markdown]
# **(b) [20 pts]** Now list the top 10 most frequently occurring entities (entity text and the number of occurence) with label `ORG` (organization). Separately list the top 10 most frequently occurring entities with label `GPE` (geopolitical entity such as countries, cities, states) respectively. **In both cases, please convert the entity names to lowercase first before computing the top 10.**
#
# Here, when counting the (raw count) frequency, we need to count how many articles have an entity with the desired property. For every article, we add 1 if the article has the entity and 0 otherwise.

# %%
ORG_counter = Counter()

for tokens in reuters_nlp:
    l =[]
    for token in tokens.ents:
        original_token_text = token.orth_.lower()
        if token.label_ == 'ORG':
            ORG_counter[original_token_text] += 1
            if  original_token_text in l:
                 ORG_counter[original_token_text] = ORG_counter[original_token_text] - 1
            l.append(original_token_text)

ORG_sorted_token_count_pairs = ORG_counter.most_common(10)
for token, count in ORG_sorted_token_count_pairs:
    print(token, ":", count)
# Out:
# cts : 1115
# reuters : 444
# the securities and exchange commission : 248
# ec : 231
# fed : 230
# treasury : 228
# cts net : 179
# the u.s. agriculture department : 170
# usda : 154
# the bank of england : 143

# %%
    
GPE_counter = Counter()
for tokens in reuters_nlp:
    l=[]
    for token in tokens.ents:
        original_token_text = token.orth_.lower()
        if token.label_ == 'GPE':
            GPE_counter[original_token_text] += 1
            if  original_token_text in l:
                 GPE_counter[original_token_text] = GPE_counter[original_token_text] - 1
            l.append(original_token_text)

GPE_sorted_token_count_pairs = GPE_counter.most_common(10)
for token, count in GPE_sorted_token_count_pairs:
    print(token, ":", count)
# Out:
# u.s. : 1631
# japan : 579
# the united states : 383
# u.k. : 297
# canada : 295
# new york : 251
# west germany : 236
# washington : 230
# london : 216
# brazil : 201

# %% [markdown]
# **(c) [20 pts]** Give the top 50 `GPE` (countries, cities, states) entities that have the highest Pointwise Mutual Information (PMI) values with regard to the `ORG` (organization) entity **'opec'** (your list of this top 50 should be ranked in decreasing PMI value). Did you find any unexpected results? If so, why do you think it happened? If you found some of the results to be unsurprisingly, how come? **Just like in the previous part, please convert entity names to lowercase in your analysis.**
#
# Hint 1: As in lecture, when computing PMI, we will compute probabilities by counting the number of documents where entities occur or co-occur.  For example, $P('opec') = \frac{number \ \ of \ \ documents \ \ containing \ \ 'opec'}{number \ \ of \ \ documents}$.
#
# Hint 2: To compute this ranking, you do not have to compute the full PMI equation.

# %%
pairs = [(token[0],'opec') for token in GPE_counter.items()]

# %%
co_occurrence_prob = Counter()

for pair in pairs:
    co_occurrence_count = 0
    for doc in reuters_nlp:
        doc_list = []
        for ent in doc.ents:
            doc_list.append([ent.text.lower(),ent.label_])
        if ['opec','ORG'] in doc_list and [pair[0],'GPE'] in doc_list:
            co_occurrence_count += 1
    co_occurrence_prob[('opec',pair[0])] = co_occurrence_count / len(reuters_nlp)

co_occurrence_prob
# Out:
# Counter({('opec', 'u.s.'): 0.003615127919911012,
#          ('opec', 'japan'): 0.0010196514645902854,
#          ('opec', 'tokyo'): 0.0003707823507601038,
#          ('opec', 'taiwan'): 0.0,
#          ('opec', "south korea's"): 0.0,
#          ('opec', 'south korea'): 0.0,
#          ('opec', 'malaysia'): 0.00027808676307007786,
#          ('opec', 'hong kong'): 0.0,
#          ('opec', "hong kong's"): 0.0,
#          ('opec', 'canberra'): 0.0,
#          ('opec', 'australia'): 9.269558769002595e-05,
#          ('opec', 'makoto kuroda'): 0.0,
#          ('opec', 'washington'): 0.00027808676307007786,
#          ('opec', 'china'): 9.269558769002595e-05,
#          ('opec', 'thailand'): 0.0,
#          ('opec', 'indonesia'): 0.0005561735261401557,
#          ('opec', 'rotterdam'): 0.0,
#          ('opec', 'new south wales'): 0.0,
#          ('opec', 'victoria'): 0.0,
#          ('opec', 'sydney'): 0.0,
#          ('opec', 'newcastle'): 0.0,
#          ('opec', 'mexico'): 0.0005561735261401557,
#          ('opec', 'osaka'): 0.0,
#          ('opec', 'banca del gottardo'): 0.0,
#          ('opec', 'gottardo'): 0.0,
#          ('opec', 'philippines'): 0.0,
#          ('opec', 'cebu'): 0.0,
#          ('opec', 'canada'): 0.0006488691138301817,
#          ('opec', 'brazil'): 0.0,
#          ('opec', 'u.k.'): 0.0003707823507601038,
#          ('opec', '505'): 0.0,
#          ('opec', 'seoul'): 0.0,
#          ('opec', 'the united states'): 0.0007415647015202076,
#          ('opec', 'finland'): 0.0,
#          ('opec', 'edmonton'): 0.0,
#          ('opec', 'vancouver'): 0.0,
#          ('opec', 'b.c.'): 0.0,
#          ('opec', 'saudi arabia'): 0.002502780867630701,
#          ('opec', 'alberta'): 9.269558769002595e-05,
#          ('opec', 'norway'): 0.0004634779384501298,
#          ('opec', 'oslo'): 0.0,
#          ('opec', 'britain'): 0.0006488691138301817,
#          ('opec', 'spain'): 9.269558769002595e-05,
#          ('opec', 'portugal'): 0.0,
#          ('opec', 'singapore'): 0.0001853911753800519,
#          ('opec', 'san miguel'): 0.0,
#          ('opec', 'new york'): 0.0004634779384501298,
#          ('opec', 'melbourne'): 0.0,
#          ('opec', 'kuwait'): 0.002502780867630701,
#          ('opec', 'new zealand'): 0.0,
#          ('opec', 'london'): 0.0003707823507601038,
#          ('opec', 'manila'): 0.0,
#          ('opec', "los angeles'"): 0.0,
#          ('opec', 'cojuangco'): 0.0,
#          ('opec', 'united states'): 0.0,
#          ('opec', 'neptunia'): 0.0,
#          ('opec', 'u.s'): 0.0,
#          ('opec', 'queensland'): 0.0,
#          ('opec', 'bundaberg'): 0.0,
#          ('opec', 'florence'): 0.0,
#          ('opec', 'fondiaria'): 0.0,
#          ('opec', 'west germany'): 0.0003707823507601038,
#          ('opec', 'california'): 0.0,
#          ('opec', 'flevoland'): 0.0,
#          ('opec', 'amsterdam'): 0.0,
#          ('opec', 'hawaii'): 0.0,
#          ('opec', 'avg'): 0.0,
#          ('opec', 'uk'): 9.269558769002595e-05,
#          ('opec', 'tonnes'): 0.0,
#          ('opec', 'paris'): 0.0001853911753800519,
#          ('opec', 'stoltenberg'): 0.0,
#          ('opec', 'france'): 0.00027808676307007786,
#          ('opec', 'belgium 18,500'): 0.0,
#          ('opec', 'denmark'): 0.0,
#          ('opec', 'netherlands'): 0.0,
#          ('opec', 'west-germany'): 0.0,
#          ('opec', 'salem'): 0.0,
#          ('opec', 'ore.'): 0.0,
#          ('opec', 'paramus'): 0.0,
#          ('opec', 'n.j.'): 0.0,
#          ('opec', 'wayne'): 0.0,
#          ('opec', 'hackensack'): 0.0,
#          ('opec', 'fla.'): 0.0,
#          ('opec', 'myrtle beach'): 0.0,
#          ('opec', 's.c.'): 0.0,
#          ('opec', 'houston'): 0.0,
#          ('opec', 'louisville'): 0.0,
#          ('opec', 'nashville'): 0.0,
#          ('opec', 'tenn'): 0.0,
#          ('opec', 'buenos aires'): 0.0,
#          ('opec', 'cordoba'): 0.0,
#          ('opec', 'chaco'): 0.0,
#          ('opec', 'formosa'): 0.0,
#          ('opec', 'la pampa'): 0.0,
#          ('opec', 'sorghum'): 0.0,
#          ('opec', 'santa fe'): 0.0,
#          ('opec', 'italy'): 0.0001853911753800519,
#          ('opec', 'stowe'): 0.0,
#          ('opec', 'source'): 0.0,
#          ('opec', 'kentucky'): 0.0,
#          ('opec', 'chicago'): 9.269558769002595e-05,
#          ('opec', 'u.s.-dlr'): 0.0,
#          ('opec', 'ivory coast'): 0.0,
#          ('opec', 'ghana'): 0.0,
#          ('opec', 'honduras'): 0.0,
#          ('opec', 'brasilia'): 0.0,
#          ('opec', 'sao paulo'): 0.0,
#          ('opec', 'parana'): 0.0,
#          ('opec', 'providence'): 0.0,
#          ('opec', 'madeira'): 0.0,
#          ('opec', 'agrimont'): 0.0,
#          ('opec', 'conserv'): 0.0,
#          ('opec', 'argimont'): 0.0,
#          ('opec', 'florida'): 0.0,
#          ('opec', 'montreal'): 0.0,
#          ('opec', 'cannon'): 0.0,
#          ('opec', 'north carolina'): 0.0,
#          ('opec', 'south carolina'): 0.0,
#          ('opec', 'darlington county'): 0.0,
#          ('opec', 'fayetteville'): 0.0,
#          ('opec', 'n.c.'): 0.0,
#          ('opec', 'new york series'): 0.0,
#          ('opec', 'luxembourg'): 0.0001853911753800519,
#          ('opec', 'rwanda'): 0.0,
#          ('opec', 'moscow'): 9.269558769002595e-05,
#          ('opec', 'colombia'): 0.0003707823507601038,
#          ('opec', 'turkey'): 0.0003707823507601038,
#          ('opec', 'greece'): 0.0,
#          ('opec', 'athens'): 0.0,
#          ('opec', 'comstock'): 0.0,
#          ('opec', 'pakistan'): 0.0,
#          ('opec', 'atlantic city'): 0.0,
#          ('opec', 'ecuador'): 0.0023173896922506487,
#          ('opec', 'iraq'): 0.0011123470522803114,
#          ('opec', 'basra'): 0.0,
#          ('opec', 'iran'): 0.0010196514645902854,
#          ('opec', 'baghdad'): 9.269558769002595e-05,
#          ('opec', 'texas'): 0.0001853911753800519,
#          ('opec', 'the united kingdom'): 0.0,
#          ('opec', 'alaska'): 0.00027808676307007786,
#          ('opec', 'new york real'): 0.0,
#          ('opec', 'atlanta'): 0.0,
#          ('opec', 'detroit'): 0.0,
#          ('opec', 'st. louis'): 0.0,
#          ('opec', 'd.c.'): 0.0,
#          ('opec', 'san francisco'): 0.0,
#          ('opec', 'tehran'): 0.0,
#          ('opec', 'orange'): 0.0,
#          ('opec', 'calif.'): 0.0,
#          ('opec', 'talks'): 0.0,
#          ('opec', 'british columbia'): 0.0,
#          ('opec', 'molybdenum'): 0.0,
#          ('opec', 'xebec'): 0.0,
#          ('opec', 'nevada'): 0.0,
#          ('opec', 'egypt'): 0.0004634779384501298,
#          ('opec', 'minneapolis'): 0.0,
#          ('opec', 'minn.'): 0.0,
#          ('opec', 'argentina'): 0.0,
#          ('opec', 'south africa'): 9.269558769002595e-05,
#          ('opec', 'germany'): 0.0,
#          ('opec', 'radevormwald'): 0.0,
#          ('opec', 'lousiana'): 0.0,
#          ('opec', 'ontario'): 0.0,
#          ('opec', 'morocco'): 0.0,
#          ('opec', 'hawkeye'): 0.0,
#          ('opec', 'arango'): 0.0,
#          ('opec', 'old crow'): 0.0,
#          ('opec', 'delhi'): 0.0,
#          ('opec', 'seram'): 0.0,
#          ('opec', 'hainan island'): 0.0,
#          ('opec', 'uruguay'): 0.0,
#          ('opec', 'venezuela'): 0.0015758249907304412,
#          ('opec', 'bahrain'): 0.00027808676307007786,
#          ('opec', 'stg'): 0.0,
#          ('opec', 'west berlin'): 0.0,
#          ('opec', 'england'): 0.0,
#          ('opec', 'shanxi'): 0.0,
#          ('opec', 'henan'): 0.0,
#          ('opec', 'sichuan'): 0.0,
#          ('opec', 'anhui'): 0.0,
#          ('opec', 'hebei'): 0.0,
#          ('opec', 'jiangsu'): 0.0,
#          ('opec', 'shandong'): 0.0,
#          ('opec', 'bahamas'): 0.0,
#          ('opec', 'shanghai'): 0.0,
#          ('opec', 'u.s. dlr'): 0.0,
#          ('opec', 'belgium'): 9.269558769002595e-05,
#          ('opec', 'cargill'): 0.0,
#          ('opec', 'india'): 0.0,
#          ('opec', 'johor'): 0.0,
#          ('opec', 'geneva'): 0.00027808676307007786,
#          ('opec', 'oldham'): 0.0,
#          ('opec', 'dlrs'): 0.0,
#          ('opec', 'us'): 9.269558769002595e-05,
#          ('opec', 'frankfurt'): 0.0,
#          ('opec', 'zurich'): 0.0,
#          ('opec', 'milan'): 0.0,
#          ('opec', 'basle'): 0.0,
#          ('opec', 'algeria'): 0.0005561735261401557,
#          ('opec', 'the hague'): 0.0,
#          ('opec', 'febraury'): 0.0,
#          ('opec', 'yen'): 0.0,
#          ('opec', 'rhineland'): 0.0,
#          ('opec', 'san joaquin valley'): 0.0,
#          ('opec', 'san diego'): 0.0,
#          ('opec', 'los angeles'): 0.0,
#          ('opec', 'the kingdom of belgium'): 0.0,
#          ('opec', 'the soviet union'): 0.0004634779384501298,
#          ('opec', 'switzerland'): 0.0,
#          ('opec', 'aqaba'): 0.0,
#          ('opec', 'buenaventura'): 0.0,
#          ('opec', 'naples'): 0.0,
#          ('opec', 'venice'): 0.0,
#          ('opec', 'east london'): 0.0,
#          ('opec', 'savona'): 0.0,
#          ('opec', 'antwerp'): 9.269558769002595e-05,
#          ('opec', 'tres'): 0.0,
#          ('opec', "sri lanka's"): 0.0,
#          ('opec', 'bonn'): 0.0,
#          ('opec', 'america'): 9.269558769002595e-05,
#          ('opec', 'ussr'): 0.0,
#          ('opec', 'peru'): 0.0,
#          ('opec', 'linares'): 0.0,
#          ('opec', 'port pirie'): 0.0,
#          ('opec', 'south australia'): 0.0,
#          ('opec', 'boss'): 0.0,
#          ('opec', 'montana'): 0.0,
#          ('opec', 'gothenburg'): 0.0,
#          ('opec', 'trail'): 0.0,
#          ('opec', 'kimberley'): 0.0,
#          ('opec', 'mo'): 0.0,
#          ('opec', 'new brunswick'): 0.0,
#          ('opec', 'waccamaw'): 0.0,
#          ('opec', 'dollar'): 0.0,
#          ('opec', 'purolator'): 0.0,
#          ('opec', 'abbott'): 0.0,
#          ('opec', 'great south beach'): 0.0,
#          ('opec', 'yugoslavia'): 0.0,
#          ('opec', 'belgrade'): 0.0,
#          ('opec', 'generally'): 0.0,
#          ('opec', 'nairobi'): 0.0,
#          ('opec', 'kenya'): 0.0,
#          ('opec', 'brown'): 0.0,
#          ('opec', 'phoenix'): 0.0,
#          ('opec', 'rexham'): 0.0,
#          ('opec', 'the netherlands'): 0.0,
#          ('opec', 'sweden'): 0.0001853911753800519,
#          ('opec', 'ingersoll'): 0.0,
#          ('opec', 'quebec'): 0.0,
#          ('opec', 'bradford'): 0.0,
#          ('opec', 'yaounde'): 0.0,
#          ('opec', 'plaza'): 0.0,
#          ('opec', 'new jersey'): 0.0,
#          ('opec', 'weather'): 0.0,
#          ('opec', 'calabria'): 0.0,
#          ('opec', 'rome'): 0.0,
#          ('opec', 'maputo'): 0.0,
#          ('opec', 'swaziland'): 0.0,
#          ('opec', 'new orleans'): 0.0,
#          ('opec', 'santa cruz'): 0.0,
#          ('opec', 'ala.'): 0.0,
#          ('opec', 'new york grain'): 0.0,
#          ('opec', 'fiji'): 0.0,
#          ('opec', 'libya'): 0.0005561735261401557,
#          ('opec', 'toledo'): 0.0,
#          ('opec', 'plate'): 0.0,
#          ('opec', 'miami'): 0.0,
#          ('opec', 'ktxa'): 0.0,
#          ('opec', 'dallas'): 0.0,
#          ('opec', 'herculaneum'): 0.0,
#          ('opec', 'mo.'): 0.0,
#          ('opec', 'mayaguez'): 0.0,
#          ('opec', 'puerto rico'): 0.0,
#          ('opec', 'zimbabwe'): 0.0,
#          ('opec', 'matabeleland'): 0.0,
#          ('opec', 'botswana'): 0.0,
#          ('opec', 'zambia'): 0.0,
#          ('opec', 'wheat'): 0.0,
#          ('opec', 'toronto'): 0.0,
#          ('opec', 'midland'): 0.0,
#          ('opec', 'o.o.p'): 0.0,
#          ('opec', 'cottonseed'): 0.0,
#          ('opec', 'soft'): 0.0,
#          ('opec', 'oceania'): 0.0,
#          ('opec', 'e.c.'): 0.0,
#          ('opec', 'supply'): 0.0,
#          ('opec', "south africa's"): 0.0,
#          ('opec', 'aurora'): 0.0,
#          ('opec', 'ohio'): 0.0,
#          ('opec', 'jordan'): 9.269558769002595e-05,
#          ('opec', 'michigan'): 0.0,
#          ('opec', 'centel'): 0.0,
#          ('opec', '0.40'): 0.0,
#          ('opec', 'murdochville, quebec'): 0.0,
#          ('opec', "the united states'"): 9.269558769002595e-05,
#          ('opec', 'portland'): 0.0,
#          ('opec', 'new york city'): 0.0,
#          ('opec', 'iv'): 0.0,
#          ('opec', 'illinois'): 0.0,
#          ('opec', 'iowa'): 0.0,
#          ('opec', 'minn'): 0.0,
#          ('opec', 'n.d.'): 0.0,
#          ('opec', 's.d.'): 0.0,
#          ('opec', 'ill.'): 0.0,
#          ('opec', 'sealy'): 0.0,
#          ('opec', 'the netherlands sixth offshore licensing round'): 0.0,
#          ('opec', 'bristol'): 0.0,
#          ('opec', 'lubbock'): 0.0,
#          ('opec', 'israel'): 0.0,
#          ('opec', 'zaire'): 0.0,
#          ('opec', 'murdochville'): 0.0,
#          ('opec', 'denver'): 0.0,
#          ('opec', 'spartech'): 0.0,
#          ('opec', 'europe'): 0.0,
#          ('opec', 'louisiana'): 0.0,
#          ('opec', 'greenwood'): 0.0,
#          ('opec', 'necochea'): 0.0,
#          ('opec', 'san nicolas'): 0.0,
#          ('opec', 'puerto alvear'): 0.0,
#          ('opec', 'hurting'): 0.0,
#          ('opec', 'balao'): 0.0007415647015202076,
#          ('opec', 'dominican republic'): 0.0,
#          ('opec', 'haiti'): 0.0,
#          ('opec', 'taipei'): 0.0,
#          ('opec', 'sama'): 0.0,
#          ('opec', 'uganda'): 0.0,
#          ('opec', 'mombasa'): 0.0,
#          ('opec', 'kampala'): 0.0,
#          ('opec', 'hungary'): 0.0,
#          ('opec', 'poland'): 0.0,
#          ('opec', 'the united arab emirates central bank'): 0.0,
#          ('opec', 'guangdong'): 0.0,
#          ('opec', 'chile'): 0.0,
#          ('opec', 'peking'): 0.0,
#          ('opec', 'calgary'): 0.0,
#          ('opec', 'the city of london'): 0.0,
#          ('opec', 'hague'): 0.0,
#          ('opec', 'st.gobain netherlands'): 0.0,
#          ('opec', 'papua new guinea'): 0.0,
#          ('opec', 'merlin'): 0.0,
#          ('opec', 'hamburg'): 0.0,
#          ('opec', 'munich'): 0.0,
#          ('opec', 'australasia'): 0.0,
#          ('opec', 'new aluminium'): 0.0,
#          ('opec', 'the kingdom'): 0.0,
#          ('opec', 'drew'): 9.269558769002595e-05,
#          ('opec', 'zambian'): 0.0,
#          ('opec', 'safco'): 0.0,
#          ('opec', "south atlantic's"): 0.0,
#          ('opec', 'south atlantic'): 0.0,
#          ('opec', 'independence'): 0.0,
#          ('opec', "west germany's"): 0.0,
#          ('opec', 'kansas city'): 0.0,
#          ('opec', 'st louis'): 0.0,
#          ('opec', 'massachusetts'): 0.0,
#          ('opec', 'new hampshire'): 0.0,
#          ('opec', 'double'): 0.0,
#          ('opec', 'hecla'): 0.0,
#          ('opec', 'stibnite'): 0.0,
#          ('opec', 'idaho'): 0.0,
#          ('opec', 'pentland'): 0.0,
#          ('opec', 'equador'): 0.0,
#          ('opec', 'the canary islands'): 0.0,
#          ('opec', 'comalco'): 0.0,
#          ('opec', 'goldendale'): 0.0,
#          ('opec', 'wash.'): 0.0,
#          ('opec', 'hermiston'): 0.0,
#          ('opec', 'little rock'): 0.0,
#          ('opec', 'ark.'): 0.0,
#          ('opec', 'joske'): 0.0,
#          ('opec', 'arizona'): 0.0,
#          ('opec', 'crowley'): 0.0,
#          ('opec', 'livingston'): 0.0,
#          ('opec', 'bulgaria'): 0.0,
#          ('opec', 'romania'): 0.0,
#          ('opec', 'jeddah'): 0.0,
#          ('opec', 'kuwaiti'): 0.00027808676307007786,
#          ('opec', 'khor'): 0.0,
#          ('opec', 'the united arab emirates'): 0.0010196514645902854,
#          ('opec', 'quito'): 0.0003707823507601038,
#          ('opec', 'delaware'): 0.0,
#          ('opec', 'connecticut'): 0.0,
#          ('opec', 'huron'): 0.0,
#          ('opec', 'south dakota'): 0.0,
#          ('opec', 'irvine'): 0.0,
#          ('opec', 'vismara'): 0.0,
#          ('opec', 'san/bar'): 0.0,
#          ('opec', 'county'): 0.0,
#          ('opec', 'smith'): 0.0,
#          ('opec', 'allegheny'): 0.0,
#          ('opec', 'coconut grove'): 0.0,
#          ('opec', 'roland'): 0.0,
#          ('opec', 'datagraph'): 0.0,
#          ('opec', 'lich'): 0.0,
#          ('opec', 'santa barbara'): 0.0,
#          ('opec', 'aristech'): 0.0,
#          ('opec', 'rhode island'): 0.0,
#          ('opec', 'boston'): 0.0,
#          ('opec', 'henderson'): 0.0,
#          ('opec', 'carbide'): 0.0,
#          ('opec', 'cheyenne'): 0.0,
#          ('opec', 'wyo'): 0.0,
#          ('opec', 'wyo.'): 0.0,
#          ('opec', 'intelsa'): 0.0,
#          ('opec', 'telefonica'): 0.0,
#          ('opec', 'virginia'): 0.0,
#          ('opec', 'maryland'): 9.269558769002595e-05,
#          ('opec', 'the district of columbia'): 0.0,
#          ('opec', 'philadelphia'): 0.0,
#          ('opec', 'qatar'): 0.0013904338153503894,
#          ('opec', 'ariz.'): 0.0,
#          ('opec', 'cincinnati'): 0.0,
#          ('opec', 'bensenville'): 0.0,
#          ('opec', 'newmont'): 0.0,
#          ('opec', 'deposits'): 0.0,
#          ('opec', 'mount sinai'): 0.0,
#          ('opec', 'atlantic richfield'): 0.0,
#          ('opec', 'far hills'): 0.0,
#          ('opec', 'indiana'): 0.0,
#          ('opec', 'new york state'): 0.0,
#          ('opec', 'wellsville'): 0.0,
#          ('opec', 'andover'): 0.0,
#          ('opec', 'scio'): 0.0,
#          ('opec', 'willing'): 0.0,
#          ('opec', 'belmont'): 0.0,
#          ('opec', 'milo'): 0.0,
#          ('opec', 'jerusalem'): 0.0,
#          ('opec', 'benton'): 0.0,
#          ('opec', 'n.y.'): 0.0,
#          ('opec', 'mich.'): 0.0,
#          ('opec', 'lago agrio'): 9.269558769002595e-05,
#          ('opec', 'puerto colon'): 0.0,
#          ('opec', "new zealand's"): 0.0,
#          ('opec', 'the dominican republic'): 0.0,
#          ('opec', 'qinghai province'): 0.0,
#          ('opec', 'macao'): 0.0,
#          ('opec', 'janauary'): 0.0,
#          ('opec', 'announce'): 0.0,
#          ('opec', 'equaly'): 0.0,
#          ('opec', 'rowan'): 0.0,
#          ('opec', 'orlando'): 0.0,
#          ('opec', 'lewiston'): 0.0,
#          ('opec', 'mont.'): 0.0,
#          ('opec', 'pittsburgh'): 0.0,
#          ('opec', 'pa.'): 0.0,
#          ('opec', 'guatemala'): 0.0,
#          ('opec', 'costa rica'): 0.0,
#          ('opec', 'nakasone'): 0.0,
#          ('opec', 'cleveland'): 0.0,
#          ('opec', 'carling'): 0.0,
#          ('opec', 'nigeria'): 0.0008342602892102336,
#          ('opec', 'morobe province'): 0.0,
#          ('opec', 'brussels'): 0.0,
#          ('opec', 'vienna'): 0.0015758249907304412,
#          ('opec', 'coniston'): 0.0,
#          ('opec', 'sri lanka'): 0.0,
#          ('opec', 'tunisia'): 0.0,
#          ('opec', 'sunnyvale'): 0.0,
#          ('opec', 'copperbelt'): 0.0,
#          ('opec', 'bombay'): 0.0,
#          ('opec', 'conneticut'): 0.0,
#          ('opec', "saudi arabia's"): 0.0010196514645902854,
#          ('opec', 'oklahoma'): 0.0,
#          ('opec', 'washita'): 0.0,
#          ('opec', 'great britain'): 0.0,
#          ('opec', 'gloucestershire'): 0.0,
#          ('opec', 'harcourt'): 0.0,
#          ('opec', 'manhattan'): 0.0,
#          ('opec', 'steinberg'): 0.0,
#          ('opec', '11:14:25.82'): 0.0,
#          ('opec', 'lowell'): 0.0,
#          ('opec', 'mass.'): 0.0,
#          ('opec', 'jersey city'): 0.0,
#          ('opec', 'beaufort'): 0.0,
#          ('opec', 'biloxi'): 0.0,
#          ('opec', 'miss.'): 0.0,
#          ('opec', 'humbrol'): 0.0,
#          ('opec', 'unita county'): 0.0,
#          ('opec', 'chibougamau'): 0.0,
#          ('opec', 'va.'): 0.0,
#          ('opec', 'the state of connecticut'): 0.0,
#          ('opec', 'thomaston'): 0.0,
#          ('opec', 'conn.'): 0.0,
#          ('opec', 'west chester'): 0.0,
#          ('opec', 'wisconsin'): 0.0,
#          ('opec', 'pennsylvania'): 0.0,
#          ('opec', 'the garden city'): 0.0,
#          ('opec', 'west africa'): 0.0,
#          ('opec', 'santa clara'): 0.0,
#          ('opec', 'kuala lumpur'): 0.0,
#          ('opec', 'jacksonville'): 0.0,
#          ('opec', 'the federal republic of germany'): 0.0,
#          ('opec', 'korea'): 0.0,
#          ('opec', 'ccc'): 0.0,
#          ('opec', 'drysdale'): 0.0,
#          ('opec', 'oregon'): 0.0,
#          ('opec', 'camas'): 0.0,
#          ('opec', 'salt lake city'): 0.0,
#          ('opec', 'utah'): 0.0,
#          ('opec', 'cushing'): 0.0,
#          ('opec', 'saddle brook'): 0.0,
#          ('opec', 'hutton'): 0.0,
#          ('opec', 'synar'): 0.0,
#          ('opec', 'keene'): 0.0,
#          ('opec', 'n.h.'): 0.0,
#          ('opec', 'fort worth'): 0.0,
#          ('opec', 'masco'): 0.0,
#          ('opec', 'uspci'): 0.0,
#          ('opec', 'fargo'): 0.0,
#          ('opec', 'dekalb'): 0.0,
#          ('opec', 'geurin'): 0.0,
#          ('opec', 'sarasota'): 0.0,
#          ('opec', 'samjens'): 0.0,
#          ('opec', 'georgia'): 0.0,
#          ('opec', 'azpurua'): 0.0,
#          ('opec', 'alcasa'): 0.0,
#          ('opec', 'monier'): 0.0,
#          ('opec', 'redland'): 0.0,
#          ('opec', 'south-west queensland'): 0.0,
#          ('opec', 'yunnan'): 0.0,
#          ('opec', 'guangxi'): 0.0,
#          ('opec', 'guangdong province'): 0.0,
#          ('opec', 'fujian'): 0.0,
#          ('opec', 'heilongjiang'): 0.0,
#          ('opec', 'qinghai'): 0.0,
#          ('opec', 'cuba'): 0.0,
#          ('opec', 'riyadh'): 0.0003707823507601038,
#          ('opec', 'philmac'): 0.0,
#          ('opec', '0.27930/40'): 0.0,
#          ('opec', 'geelong'): 0.0,
#          ('opec', 'nadi'): 0.0,
#          ('opec', 'lautoka'): 0.0,
#          ('opec', 'premadasa'): 0.0,
#          ('opec', 'new delhi'): 0.0,
#          ('opec', 'kansas'): 0.0,
#          ('opec', 'u.s. gold'): 0.0,
#          ('opec', 'sardinia'): 0.0,
#          ('opec', 'fort lauderdale'): 0.0,
#          ('opec', 'ottawa'): 0.0,
#          ('opec', 'saarbruecken'): 0.0,
#          ('opec', 'saarland'): 0.0,
#          ('opec', 'laterriere'): 0.0,
#          ('opec', 'sebree'): 0.0,
#          ('opec', 'ky.'): 0.0,
#          ('opec', 'san juan'): 0.0,
#          ('opec', "may denmark's"): 0.0,
#          ('opec', 'baltimore'): 0.0,
#          ('opec', 'san jose'): 0.0,
#          ('opec', 'wilmington'): 0.0,
#          ('opec', 'del.'): 0.0,
#          ('opec', 'commerce township'): 0.0,
#          ('opec', 'vero beach'): 0.0,
#          ('opec', 'jamaica'): 0.0001853911753800519,
#          ('opec', 'senegal'): 0.0,
#          ('opec', 'decatur'): 0.0,
#          ('opec', 'aspen'): 0.0,
#          ('opec', 'colo.'): 0.0,
#          ('opec', 'anaheim'): 0.0,
#          ('opec', 'maclean'): 0.0,
#          ('opec', 'bangkok'): 0.0,
#          ('opec', 'sarnia'): 0.0,
#          ('opec', 'unimedia'): 0.0,
#          ('opec', 'quebec city'): 0.0,
#          ('opec', 'chicoutimi'): 0.0,
#          ('opec', 'bingham'): 0.0,
#          ('opec', 'new guinea'): 0.0,
#          ('opec', 'morenci'): 0.0,
#          ('opec', 'new mexico'): 0.0,
#          ('opec', 'rio de janeiro'): 0.0,
#          ('opec', 'peoples republic of china'): 0.0,
#          ('opec', 'holland'): 0.0,
#          ('opec', 'mitsubishi'): 0.0,
#          ('opec', 'abeles'): 0.0,
#          ('opec', 'west) germany'): 0.0,
#          ('opec', 'hongkong'): 0.0,
#          ('opec', 'austria'): 0.0,
#          ('opec', 'new zealand ltd'): 0.0,
#          ('opec', 'labasa'): 0.0,
#          ('opec', 'penang'): 0.0,
#          ('opec', 'vessel'): 0.0,
#          ('opec', 'cumberlande'): 0.0,
#          ('opec', 'new york state supreme court'): 0.0,
#          ('opec', '55.5'): 0.0,
#          ('opec', 'brent'): 0.0001853911753800519,
#          ('opec', 'd"in'): 0.0,
#          ('opec', 'labrador'): 0.0,
#          ('opec', 'saskatchewan'): 0.0,
#          ('opec', 'liberty'): 0.0,
#          ('opec', 'horsham'): 0.0,
#          ('opec', 'fairfield'): 0.0,
#          ('opec', 'nippon'): 0.0,
#          ('opec', 'kokan'): 0.0,
#          ('opec', 'syracuse'): 0.0,
#          ('opec', 'rochester'): 0.0,
#          ('opec', 'buffalo'): 0.0,
#          ('opec', 'may ecuador'): 0.0,
#          ('opec', 'zccm'): 0.0,
#          ('opec', 'dar-es-salaam'): 0.0,
#          ('opec', 'beira'): 0.0,
#          ('opec', 'santos'): 0.0,
#          ('opec', 'waterford'): 0.0,
#          ('opec', 'wyoming'): 0.0,
#          ('opec', 'johannesburg'): 0.0,
#          ('opec', 'rustenburg'): 0.0,
#          ('opec', 'weld county'): 0.0,
#          ('opec', 'harvey'): 0.0,
#          ('opec', 'la.'): 0.0,
#          ('opec', 'alvin'): 0.0,
#          ('opec', 'longview'): 0.0,
#          ('opec', 'moore'): 0.0,
#          ('opec', 'brooklyn'): 0.0,
#          ('opec', 'transco'): 0.0,
#          ('opec', 'troutdale'): 0.0,
#          ('opec', 'memphis'): 0.0,
#          ('opec', 'west virginia'): 0.0,
#          ('opec', 'monfort'): 0.0,
#          ('opec', 'pillsbury'): 0.0,
#          ('opec', 'nordic'): 9.269558769002595e-05,
#          ('opec', 'iceland'): 9.269558769002595e-05,
#          ('opec', 'brunei'): 0.0,
#          ('opec', 'asahan'): 0.0,
#          ('opec', 'albras'): 0.0,
#          ('opec', 'maine'): 0.0,
#          ('opec', 'billiob'): 0.0,
#          ('opec', 'parent'): 0.0,
#          ('opec', 'chittagong'): 0.0,
#          ('opec', 'minnesota'): 0.0,
#          ('opec', 'dalian'): 0.0,
#          ('opec', 'xingang'): 0.0,
#          ('opec', 'u.s.a'): 0.0,
#          ('opec', 'lazere'): 0.0,
#          ('opec', 'richardson'): 0.0,
#          ('opec', 'gulfstream'): 0.0,
#          ('opec', 'deluxe'): 0.0,
#          ('opec', 'troy'): 0.0,
#          ('opec', 'hci'): 0.0,
#          ('opec', 'microsemi'): 0.0,
#          ('opec', 'birmingham'): 0.0,
#          ('opec', 'karlsruhe'): 0.0,
#          ('opec', 'cologne'): 0.0,
#          ('opec', 'duisburg'): 0.0,
#          ('opec', 'greyhound'): 0.0,
#          ('opec', 'apex'): 0.0,
#          ('opec', 'cold'): 0.0,
#          ('opec', 'ireland'): 0.0,
#          ('opec', 'czechoslovakia'): 0.0,
#          ('opec', 'ethiopia'): 0.0,
#          ('opec', 'comoros'): 0.0,
#          ('opec', 'djibouti'): 0.0,
#          ('opec', 'somalia'): 0.0,
#          ('opec', 'tanzania'): 0.0,
#          ('opec', 'lawrenceville'): 0.0,
#          ('opec', 'ga.'): 0.0,
#          ('opec', 'gwinnett county'): 0.0,
#          ('opec', 'colorado'): 0.0,
#          ('opec', 'russia'): 0.0,
#          ('opec', 'the ivory coast'): 0.0,
#          ('opec', 'el salvador'): 0.0,
#          ('opec', 'nicaragua'): 0.0,
#          ('opec', 'graniere'): 0.0,
#          ('opec', 'santa monica'): 0.0,
#          ('opec', 'sunrise'): 0.0,
#          ('opec', 'fla'): 0.0,
#          ('opec', 'koether'): 0.0,
#          ('opec', 'redmond'): 0.0,
#          ('opec', 'bogota'): 0.0,
#          ('opec', 'cardenas'): 0.0,
#          ('opec', 'dublin'): 9.269558769002595e-05,
#          ('opec', 't.e.a.m.'): 0.0,
#          ('opec', 'young'): 0.0,
#          ('opec', 'alabama'): 0.0,
#          ('opec', 'kahan'): 9.269558769002595e-05,
#          ('opec', 'caracas'): 0.0004634779384501298,
#          ('opec', 'oman'): 0.0001853911753800519,
#          ('opec', 'dubai'): 0.0003707823507601038,
#          ('opec', 'icco'): 0.0,
#          ('opec', 'petromin'): 9.269558769002595e-05,
#          ('opec', 'alexandria'): 9.269558769002595e-05,
#          ('opec', 'bangladesh'): 0.0,
#          ('opec', 'munim'): 0.0,
#          ('opec', 'north korea'): 0.0,
#          ('opec', 'madrid'): 0.0,
#          ('opec', 'town'): 0.0,
#          ('opec', 'schuykill county'): 0.0,
#          ('opec', 'edison'): 0.0,
#          ('opec', 'u.s.-flag'): 0.0,
#          ('opec', 'missouri'): 0.0,
#          ('opec', 'lebanon'): 0.0,
#          ('opec', 'kearn county'): 0.0,
#          ('opec', 'new-mexico'): 0.0,
#          ('opec', 'nebraska'): 0.0,
#          ('opec', 'vernitron'): 0.0,
#          ('opec', 'oakland'): 0.0,
#          ('opec', 'newport beach'): 0.0,
#          ('opec', 'calif'): 0.0,
#          ('opec', 'youngstown'): 0.0,
#          ('opec', 'spokane'): 0.0,
#          ('opec', 'helena'): 0.0,
#          ('opec', 'canbra'): 0.0,
#          ('opec', 'murfreesboro'): 0.0,
#          ('opec', 'aruba'): 0.0,
#          ('opec', 'eurobonds'): 0.0,
#          ('opec', 'cws.to'): 0.0,
#          ('opec', 's.a.'): 0.0,
#          ('opec', 'seton'): 0.0,
#          ('opec', 'ggg.to'): 0.0,
#          ('opec', 'mill city'): 0.0,
#          ('opec', 'memorex'): 0.0,
#          ('opec', 'alba'): 0.0,
#          ('opec', 'austin'): 0.0,
#          ('opec', 'halycon'): 0.0,
#          ('opec', 'dutchess county'): 0.0,
#          ('opec', 'hanover'): 0.0,
#          ('opec', 'tilden'): 0.0,
#          ('opec', 'ogelbay'): 0.0,
#          ('opec', 'jakarta'): 0.0003707823507601038,
#          ('opec', 'sabah'): 0.0,
#          ('opec', 'shinyanga'): 0.0,
#          ('opec', 'lampe'): 0.0,
#          ('opec', 'iranian'): 0.0,
#          ('opec', 'damascus'): 0.0,
#          ('opec', 'east aceh'): 0.0,
#          ('opec', 'langsa'): 0.0,
#          ('opec', 'aceh'): 0.0,
#          ('opec', 'aqazadeh'): 9.269558769002595e-05,
#          ('opec', 'marine midland'): 0.0,
#          ('opec', 'tribunal'): 0.0,
#          ('opec', 'contac'): 0.0,
#          ('opec', 'dar es salaam'): 0.0,
#          ('opec', 'ula fields'): 9.269558769002595e-05,
#          ('opec', 'statfjord'): 9.269558769002595e-05,
#          ('opec', 'oseberg'): 9.269558769002595e-05,
#          ('opec', 'cosmo'): 0.0,
#          ('opec', 'isle city'): 0.0,
#          ('opec', 'glen oaks'): 0.0,
#          ('opec', 'ocean city'): 0.0,
#          ('opec', 'unnecessary'): 0.0,
#          ('opec', 'brescia'): 0.0,
#          ('opec', 'columbia'): 0.0,
#          ('opec', 'west virginia free'): 0.0,
#          ('opec', 'metropolitan'): 0.0,
#          ('opec', 'kenaf'): 0.0,
#          ('opec', 'auckland, new zealand'): 0.0,
#          ('opec', "new york's"): 0.0,
#          ('opec', 'sea isle city'): 0.0,
#          ('opec', 'u.s.-flagged kuwaiti'): 0.0,
#          ('opec', 'bundesbnak'): 0.0,
#          ('opec', 'diplomats'): 0.0,
#          ('opec', 'amman'): 0.0,
#          ('opec', 'kuwaitis'): 0.0,
#          ('opec', 'bp'): 9.269558769002595e-05,
#          ('opec', 'the the soviet union'): 0.0,
#          ('opec', 'sante fe'): 0.0,
#          ('opec', 'henley'): 0.0,
#          ('opec', 'renta'): 0.0,
#          ('opec', 'kfl.to'): 0.0,
#          ('opec', 'hanna'): 0.0,
#          ('opec', 'somerset'): 0.0,
#          ('opec', 'nicosia'): 0.0,
#          ('opec', 'guernsey'): 0.0,
#          ('opec', 'involves'): 0.0,
#          ('opec', 'leahy'): 0.0,
#          ('opec', 'killlington'): 0.0,
#          ('opec', 'vt.'): 0.0,
#          ('opec', 'san bernardino'): 0.0,
#          ('opec', 'boliden'): 0.0,
#          ('opec', 'pleasanton'): 0.0,
#          ('opec', 'santa ana'): 0.0,
#          ('opec', 'kingman'): 0.0,
#          ('opec', 'burro creek'): 0.0,
#          ('opec', 'clarendon'): 0.0,
#          ('opec', 'ipswich'): 0.0,
#          ('opec', 'british sugar'): 0.0,
#          ('opec', 'belzberg'): 0.0,
#          ('opec', 'republic of iran'): 0.0,
#          ('opec', 'calmat'): 0.0,
#          ('opec', 'napa'): 0.0,
#          ('opec', 'arnox'): 0.0,
#          ('opec', 'berkey'): 0.0,
#          ('opec', 'soviet union'): 0.0,
#          ('opec', 'sassan'): 0.0,
#          ('opec', 'ravenna'): 0.0,
#          ('opec', 'racine'): 0.0,
#          ('opec', 'wis.'): 0.0,
#          ('opec', 'cable'): 0.0,
#          ('opec', 'yemen'): 0.0,
#          ('opec', 'aden'): 0.0,
#          ('opec', 'shabwa'): 0.0,
#          ('opec', 'the washington d.c. area'): 0.0,
#          ('opec', 'capital'): 0.0,
#          ('opec', 'rare'): 0.0,
#          ('opec', 'yantai'): 0.0,
#          ('opec', 'no.4'): 0.0,
#          ('opec', 'matanzas'): 0.0,
#          ('opec', 'lebanese'): 0.0,
#          ('opec', 'west beirut'): 0.0,
#          ('opec', 'hong kong) ltd'): 0.0,
#          ('opec', 'new telecommunication'): 0.0,
#          ('opec', 'suva'): 0.0,
#          ('opec', 'neka'): 0.0,
#          ('opec', 'jolfa'): 0.0,
#          ('opec', 'north-west iran'): 0.0,
#          ('opec', 'n.z.'): 0.0,
#          ('opec', "the soviet union's"): 0.0,
#          ('opec', 'boksburg'): 0.0,
#          ('opec', 'new york sept'): 0.0,
#          ('opec', 'new york dec'): 0.0,
#          ('opec', 'lugano'): 0.0,
#          ('opec', 'tex.'): 0.0,
#          ('opec', 'st. paul'): 0.0,
#          ('opec', 'beaumont'): 0.0,
#          ('opec', 'gyllenhammar'): 0.0,
#          ('opec', 'alameda'): 0.0,
#          ('opec', 'san mateo'): 0.0,
#          ('opec', 'richmond'): 0.0,
#          ('opec', 'lakeview'): 0.0,
#          ('opec', 'marine'): 0.0,
#          ('opec', 'malibu'): 0.0,
#          ('opec', 'yates field'): 0.0,
#          ('opec', 'guillaume'): 0.0,
#          ('opec', 'north ridge'): 0.0,
#          ('opec', 'columbus'): 0.0,
#          ('opec', 'panama'): 0.0,
#          ('opec', 'cyprus'): 0.0,
#          ('opec', 'chesebrough'): 0.0,
#          ('opec', 'the west indies'): 0.0,
#          ('opec', 'omaha'): 0.0,
#          ('opec', 'warburg'): 0.0,
#          ('opec', 'hong kong land'): 0.0,
#          ('opec', 'busan'): 0.0,
#          ('opec', 'kaohsiung'): 0.0,
#          ('opec', 'yokohama'): 0.0,
#          ('opec', 'kobe'): 0.0,
#          ('opec', 'herald'): 0.0,
#          ('opec', '285'): 0.0,
#          ('opec', 'february thailand'): 0.0,
#          ('opec', 'n.z. dlr'): 0.0,
#          ('opec', 'alcan'): 0.0,
#          ('opec', 'nz'): 0.0,
#          ('opec', 'thyssen'): 0.0,
#          ('opec', 'progressive'): 0.0,
#          ('opec', "ivory coast's"): 0.0,
#          ('opec', 'abidjan'): 0.0,
#          ('opec', 'ankara'): 0.0,
#          ('opec', 'weissach'): 0.0,
#          ('opec', 't.b.c.'): 0.0,
#          ('opec', 'cornwall'): 0.0,
#          ('opec', 'woodward'): 0.0,
#          ('opec', 'okla.'): 0.0,
#          ('opec', 'tampa'): 0.0,
#          ('opec', 'north sydney'): 0.0,
#          ('opec', 'summitville'): 0.0,
#          ('opec', 'tennessee'): 0.0,
#          ('opec', 'mississippi'): 0.0,
#          ('opec', 'arkansas'): 0.0,
#          ('opec', 'bordeaux'): 0.0,
#          ('opec', 'brownsville'): 0.0,
#          ('opec', 'ns'): 0.0,
#          ('opec', 'shefra'): 0.0,
#          ('opec', 'valhi'): 0.0,
#          ('opec', 'n.a.'): 0.0,
#          ('opec', 'cgct'): 0.0,
#          ('opec', 'guam'): 0.0,
#          ('opec', 'kalamazoo'): 0.0,
#          ('opec', 'woodinville'): 0.0,
#          ('opec', 'canakkale'): 0.0,
#          ('opec', 'u.s./japan'): 0.0,
#          ('opec', 'emirates'): 0.0001853911753800519,
#          ('opec', 'liban'): 0.0,
#          ('opec', 'managua'): 0.0,
#          ('opec', 'intense united states'): 0.0,
#          ('opec', 'cumhuriyet'): 0.0,
#          ('opec', 'chad'): 0.0,
#          ('opec', 'new gold'): 0.0,
#          ('opec', 'san ignasio'): 0.0,
#          ('opec', 'tamborapa'): 0.0,
#          ('opec', 'superdrug'): 0.0,
#          ('opec', '144.20/40'): 0.0,
#          ('opec', 'wallenberg'): 0.0,
#          ('opec', 'nurseries'): 0.0,
#          ('opec', 'colombo'): 0.0,
#          ('opec', 'parmelia'): 0.0,
#          ('opec', 'sachs'): 0.0,
#          ('opec', '459p'): 0.0,
#          ('opec', 'zincor'): 0.0,
#          ('opec', 'lufkin'): 0.0,
#          ('opec', 'papandreou'): 0.0,
#          ('opec', 'demerara'): 0.0,
#          ('opec', 'kurunegala'): 0.0,
#          ('opec', 'kingston'): 0.0,
#          ('opec', 'stockholm'): 0.0,
#          ('opec', 'wilkinson'): 0.0,
#          ('opec', 'macon'): 0.0,
#          ('opec', 'seattle'): 0.0,
#          ('opec', 'norwest gypsum'): 0.0,
#          ('opec', 'new zealand dollars'): 0.0,
#          ('opec', 'pompano beach'): 0.0,
#          ('opec', 'lowe'): 0.0,
#          ('opec', 'willcox'): 0.0,
#          ('opec', 'baldwin county'): 0.0,
#          ('opec', 'scottsboro'): 0.0,
#          ('opec', 'demopolis'): 0.0,
#          ('opec', 'new holland'): 0.0,
#          ('opec', 'lancaster county'): 0.0,
#          ('opec', 'dunham'): 9.269558769002595e-05,
#          ('opec', 'the lake charles'): 9.269558769002595e-05,
#          ('opec', 'la'): 9.269558769002595e-05,
#          ('opec', 'r.i.'): 0.0,
#          ('opec', 'tulsa'): 0.0,
#          ('opec', 'morning'): 0.0,
#          ('opec', 'n pak'): 0.0,
#          ('opec', 'camden'): 0.0,
#          ('opec', 'orange county'): 0.0,
#          ('opec', 'tenn.'): 0.0,
#          ('opec', 'rev'): 0.0,
#          ('opec', 'strip'): 0.0,
#          ('opec', 'cooper'): 0.0,
#          ('opec', 'los angeles pr company public relations'): 0.0,
#          ('opec', 'shandwick'): 0.0,
#          ('opec', 'u.s.-japan'): 0.0,
#          ('opec', 'currency'): 0.0,
#          ('opec', 'markheath'): 0.0,
#          ('opec', 'selling delhi'): 0.0,
#          ('opec', 'farmland'): 0.0,
#          ('opec', 'ryzhkov'): 0.0,
#          ('opec', 'traditionally britain'): 0.0,
#          ('opec', 'rada'): 0.0,
#          ('opec', 'cheung kong'): 0.0,
#          ('opec', 'chernobyl'): 0.0,
#          ('opec', 'angola'): 0.0,
#          ('opec', 'the northwest territories'): 0.0,
#          ('opec', 'baytown'): 0.0,
#          ('opec', 'mairinque'): 0.0,
#          ('opec', 'republic'): 0.0,
#          ('opec', 'kan.'): 0.0,
#          ('opec', 'lake ontario'): 0.0,
#          ('opec', 'subotica'): 0.0,
#          ('opec', 'rocky mount'): 0.0,
#          ('opec', 'the soviet union lyng'): 0.0,
#          ('opec', 'north dakota'): 0.0,
#          ('opec', 'schrader'): 0.0,
#          ('opec', 'hurts'): 0.0,
#          ('opec', 'east germany'): 0.0,
#          ('opec', 'berlin'): 0.0,
#          ('opec', 'east berlin'): 0.0,
#          ('opec', 'syria'): 0.0,
#          ('opec', 'north kingstown'): 0.0,
#          ('opec', 'garland'): 0.0,
#          ('opec', 'bethesda'): 9.269558769002595e-05,
#          ('opec', 'franco'): 9.269558769002595e-05,
#          ('opec', 'quest blood'): 0.0,
#          ('opec', 'guanghdong'): 0.0,
#          ('opec', 'hunan'): 0.0,
#          ('opec', 'jiangxi'): 0.0,
#          ('opec', 'zhejiang'): 0.0,
#          ('opec', 'blackburn'): 0.0,
#          ('opec', 'lancashire'): 0.0,
#          ('opec', 'elgin'): 0.0,
#          ('opec', 'guinea'): 0.0,
#          ('opec', 'liberia'): 0.0,
#          ('opec', 'secaucus'): 0.0,
#          ('opec', 'ames'): 0.0,
#          ('opec', 'st. petersburg'): 0.0,
#          ('opec', 'lifetime'): 0.0,
#          ('opec', 'schwab'): 0.0,
#          ('opec', 'corona'): 0.0,
#          ('opec', 'cotton'): 0.0,
#          ('opec', 'magnum'): 0.0,
#          ('opec', 'sitter'): 0.0,
#          ('opec', 'eschborn'): 0.0,
#          ('opec', 'lexington'): 0.0,
#          ('opec', 'non-'): 0.0,
#          ('opec', 'new albany'): 0.0,
#          ('opec', 'tupelo'): 0.0,
#          ('opec', 'lucht'): 0.0,
#          ('opec', '0.007050'): 0.0,
#          ('opec', 'liposome'): 0.0,
#          ('opec', 'hartford'): 0.0,
#          ('opec', 'co.'): 0.0,
#          ('opec', 'first city'): 0.0,
#          ('opec', "first city's"): 0.0,
#          ('opec', 'fengbang'): 0.0,
#          ('opec', 'westlb'): 0.0,
#          ('opec', '526'): 0.0,
#          ('opec', 'the states of malaya chamber of mines'): 0.0,
#          ('opec', 'triguna'): 0.0,
#          ('opec', 'internatio'): 0.0,
#          ('opec', 'porto'): 0.0,
#          ('opec', 'visual'): 0.0,
#          ('opec', '11.6'): 0.0,
#          ('opec', 'sudan'): 0.0,
#          ('opec', 'mauritania'): 0.0,
#          ('opec', 'vanuatu'): 0.0,
#          ('opec', 'appleton'): 0.0,
#          ('opec', 'west allis'): 0.0,
#          ('opec', 'lachine'): 0.0,
#          ('opec', 'trinidad'): 0.0,
#          ('opec', 'tobago'): 0.0,
#          ('opec', 'nc'): 0.0,
#          ('opec', 'poitou-charentes'): 0.0,
#          ...})

# %%
GPE_probabilities = Counter()

for pair in pairs:
    count = 0
    for tokens in reuters_nlp:
        condition = [entity.text.lower() for entity in tokens.ents if entity.text.lower() == pair[0] and entity.label_ == 'GPE' ]
        count += 1 if condition else 0
    GPE_probabilities[pair[0]] = count / len(reuters_nlp)   
print(GPE_probabilities)
# Out:
# Counter({'u.s.': 0.15118650352243232, 'japan': 0.05367074527252503, 'the united states': 0.03550241008527994, 'u.k.': 0.02753058954393771, 'canada': 0.027345198368557658, 'new york': 0.023266592510196516, 'west germany': 0.021876158694846125, 'washington': 0.02131998516870597, 'london': 0.020022246941045607, 'brazil': 0.018631813125695215, 'britain': 0.017241379310344827, 'paris': 0.017055988134964777, 'france': 0.01696329254727475, 'tokyo': 0.013811642565813867, 'china': 0.0121431219873934, 'the soviet union': 0.011772339636633296, 'australia': 0.010289210233592881, 'texas': 0.010289210233592881, 'taiwan': 0.00982573229514275, 'italy': 0.009733036707452725, 'iran': 0.009547645532072673, 'avg': 0.008991472005932517, 'spain': 0.007230255839822024, 'south korea': 0.0070448646644419724, 'indonesia': 0.0070448646644419724, 'hong kong': 0.006581386725991843, 'kuwait': 0.006303299962921765, 'iraq': 0.006303299962921765, 'california': 0.006117908787541713, 'saudi arabia': 0.005932517612161661, 'ussr': 0.005839822024471635, 'malaysia': 0.0055617352614015575, 'chicago': 0.0055617352614015575, 'ecuador': 0.0052836484983314795, 'india': 0.0052836484983314795, 'moscow': 0.005098257322951428, 'singapore': 0.005005561735261402, 'colombia': 0.005005561735261402, 'new zealand': 0.00482017055988135, 'netherlands': 0.00482017055988135, 'ohio': 0.004727474972191324, 'venezuela': 0.0043566926214312195, 'thailand': 0.004263997033741194, 'mexico': 0.004171301446051168, 'sweden': 0.004171301446051168, 'philippines': 0.004078605858361142, 'stg': 0.004078605858361142, 'florida': 0.003985910270671116, 'houston': 0.00389321468298109, 'calif.': 0.00389321468298109, 'egypt': 0.003800519095291064, 'south africa': 0.003800519095291064, 'belgium': 0.003800519095291064, 'switzerland': 0.0037078235076010383, 'turkey': 0.003615127919911012, 'dallas': 0.0035224323322209862, "west germany's": 0.0035224323322209862, 'germany': 0.0034297367445309604, 'kuwaiti': 0.0034297367445309604, 'algeria': 0.0033370411568409346, 'u.s': 0.0032443455691509083, 'bonn': 0.0032443455691509083, 'norway': 0.0031516499814608825, 'uk': 0.0031516499814608825, 'greece': 0.0031516499814608825, 'argentina': 0.0031516499814608825, 'denmark': 0.0029662588060808304, 'los angeles': 0.0029662588060808304, 'america': 0.0029662588060808304, 'peru': 0.0029662588060808304, 'portugal': 0.0027808676307007787, 'louisiana': 0.0027808676307007787, 'n.j.': 0.002688172043010753, 'illinois': 0.002688172043010753, 'the united arab emirates': 0.002688172043010753, 'rotterdam': 0.002502780867630701, 'fla.': 0.002502780867630701, 'pakistan': 0.002502780867630701, 'uruguay': 0.002502780867630701, 'quebec': 0.002502780867630701, "south korea's": 0.002410085279940675, 'ontario': 0.002410085279940675, 'bahrain': 0.002410085279940675, 'qatar': 0.002410085279940675, 'geneva': 0.0023173896922506487, 'frankfurt': 0.0023173896922506487, 'n.y.': 0.002224694104560623, 'oklahoma': 0.002224694104560623, 'luxembourg': 0.002131998516870597, 'new jersey': 0.002131998516870597, 'toronto': 0.002039302929180571, 'michigan': 0.002039302929180571, 'portland': 0.002039302929180571, 'venice': 0.001946607341490545, "south africa's": 0.001946607341490545, 'delaware': 0.001946607341490545, 'tehran': 0.0018539117538005192, 'us': 0.0018539117538005192, 'peking': 0.0018539117538005192, "new zealand's": 0.0018539117538005192, 'vienna': 0.0018539117538005192, 'alaska': 0.0017612161661104931, 'british columbia': 0.0017612161661104931, 'costa rica': 0.0017612161661104931, 'sorghum': 0.0016685205784204673, 'kenya': 0.0016685205784204673, 'iowa': 0.0016685205784204673, 'ill.': 0.0016685205784204673, 'hamburg': 0.0016685205784204673, 'indiana': 0.0016685205784204673, 'nigeria': 0.0016685205784204673, 'kansas': 0.0016685205784204673, 'minnesota': 0.0016685205784204673, 'vancouver': 0.0015758249907304412, 'alberta': 0.0015758249907304412, 'minneapolis': 0.0015758249907304412, 'dlrs': 0.0015758249907304412, 'israel': 0.0015758249907304412, 'brussel ...

# %%
OPEC_probabilities = Counter()

count = 0
for tokens in reuters_nlp:
    condition = [entity.text.lower() for entity in tokens.ents if entity.text.lower() == 'opec']
    count += 1 if condition else 0
        
opec_probabilities = count / len(reuters_nlp)
print(count,opec_probabilities)
# Out:
# 122 0.011308861698183166

# %%
from math import log  
pmi_scores = Counter()
for opec, token in dict(co_occurrence_prob).keys():
    if co_occurrence_prob[('opec',token)] != 0 and GPE_probabilities[token] !=0 :
        ratio = co_occurrence_prob[('opec',token)] / (GPE_probabilities[token] * opec_probabilities)
        pmi_scores[token] = log(ratio)
    
pmi_scores.most_common(50)
# Out:
# [('brent', 4.482168639526364),
#  ('ula fields', 4.482168639526364),
#  ('emirates', 4.482168639526364),
#  ('the lake charles', 4.482168639526364),
#  ('bethesda', 4.482168639526364),
#  ('franco', 4.482168639526364),
#  ('gabon', 4.482168639526364),
#  ('opec', 4.482168639526364),
#  ('saudi arabia reiterates commitment to', 4.482168639526364),
#  ('yanbu', 4.482168639526364),
#  ('el salado', 4.482168639526364),
#  ('aguarico', 4.482168639526364),
#  ('ras tanurah', 4.482168639526364),
#  ("ju'aymah", 4.482168639526364),
#  ('jubail', 4.482168639526364),
#  ('tripoli', 4.482168639526364),
#  ('doha', 4.482168639526364),
#  ('guayaquil', 4.482168639526364),
#  ('tihamah', 4.482168639526364),
#  ('redoglia', 4.482168639526364),
#  ('carrington', 4.482168639526364),
#  ('materialy', 4.482168639526364),
#  ('vienna', 4.319649710028589),
#  ('riyadh', 4.259025088212154),
#  ("saudi arabia's", 4.107475190084953),
#  ('balao', 4.076703531418199),
#  ('quito', 4.076703531418199),
#  ('qatar', 3.932122302607092),
#  ('dubai', 3.9225528515909414),
#  ('caracas', 3.894381974624245),
#  ('nigeria', 3.7890214589664186),
#  ('nordic', 3.7890214589664186),
#  ('kahan', 3.7890214589664186),
#  ('statfjord', 3.7890214589664186),
#  ('oseberg', 3.7890214589664186),
#  ('dunham', 3.7890214589664186),
#  ('la', 3.7890214589664186),
#  ('libya', 3.7089787512928822),
#  ('ecuador', 3.6579931965600148),
#  ('saudi arabia', 3.619122422171021),
#  ('kuwait', 3.5584978003545866),
#  ('the united arab emirates', 3.5127680823382605),
#  ('venezuela', 3.4652343818725218),
#  ('lago agrio', 3.3835563508582545),
#  ('petromin', 3.3835563508582545),
#  ('alexandria', 3.3835563508582545),
#  ('jakarta', 3.3835563508582545),
#  ('lagos', 3.3835563508582545),
#  ('jamaica', 3.229405671030996),
#  ('iceland', 3.0958742784064737)]

# %% [markdown]
# Your text answer (for this question, your answer is *not* code): *** WRITE YOUR ANSWER HERE ***

# %%
# ###
# We realize that there are many entity share the same PMI value 
# which indicate that they might occur in the same artciles
# opec, saudi arabia, emirate are the top entities 
# with most occurrence since we finding top 50 GPE regard to 'opec'
# is not surprise to see opec and middle east country in top 50
# ###
